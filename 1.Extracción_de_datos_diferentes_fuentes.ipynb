# %%
# Cargar archivos de Drive

# from google.colab import drive
# drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Almacenamos la ruta de los archivos en una variable
# ruta='/content/drive/MyDrive/Colab Notebooks/Módulo 1 - Extracción de datos de diferentes fuentes/'
ruta = ''

# %% [markdown]
# # Archivos de texto
# ### De texto a `DataFrame`

# %%
import pandas as pd

# %%
# Extracción a partir de texto separado por tabular
pd.read_fwf(ruta+'texto_2.txt', header=None)
# Out:
#          0    1   2
# 0      Ana  1.0  10
# 1     Beto  1.1  10
# 2  Alfredo  6.0   9
# 3  Armando  5.0   9

# %%
pd.read_table(ruta+'texto_2.txt', header=None)
# Out:
#           0    1   2
# 0  Ana       1.0  10
# 1  Beto      1.1  10
# 2  Alfredo   6.0   9
# 3  Armando   5.0   9

# %%
pd.read_csv(ruta+'texto_2.txt', header=None, sep='\t')
# Out:
#           0    1   2
# 0  Ana       1.0  10
# 1  Beto      1.1  10
# 2  Alfredo   6.0   9
# 3  Armando   5.0   9

# %%
# Extracción a partir de texto separado por comas, con read_table necesitas ,
pd.read_table(ruta+'texto_1.txt',sep=',',header=None)
# Out:
#          0    1   2
# 0      Ana  1.0  10
# 1     Beto  1.1  10
# 2  Alfredo  6.0   9
# 3  Armando  5.0   9

# %%
pd.read_csv(ruta+'texto_1.txt',header=None)
# Out:
#          0    1   2
# 0      Ana  1.0  10
# 1     Beto  1.1  10
# 2  Alfredo  6.0   9
# 3  Armando  5.0   9

# %% [markdown]
# ### Expresiones regulares

# %%
# Conversión de archivo a variable
file=open(ruta+'texto_3.txt')     # Abrir...
texto=file.read()
file.close()                      # ...despues cerrar

# %%
# Si ocurre un error durante la ejecución, la variable file se cierra siempre:
with open(ruta+'texto_3.txt') as file:
  texto=file.read()

# %%
texto
# Out:
# 'En un lugar de la Mancha, de cuyo nombre no quiero acordarme, no ha mucho tiempo que vivía un hidalgo de los de lanza en astillero, adarga antigua, rocón flaco y galgo corredor. Una olla de algo más vaca que carnero, salpicón las más noches, duelos y quebrantos los sábados, lantejas los viernes, algún palomino de añadidura los domingos, consumían las tres partes de su hacienda. El resto della concluían sayo de velarte, calzas de velludo para las fiestas, con sus pantuflos de lo mesmo, y los días de entresemana se honraba con su vellorí de lo más fino. Tenía en su casa una ama que pasaba de los cuarenta, y una sobrina que no llegaba a los veinte, y un mozo de campo y plaza, que así ensillaba el rocín como tomaba la podadera. Frisaba la edad de nuestro hidalgo con los cincuenta años; era de complexión recia, seco de carnes, enjuto de rostro, gran madrugador y amigo de la caza. Quieren decir que tenía el sobrenombre de Quijada, o Quesada, que en esto hay alguna diferencia en los autores que deste caso escriben; aunque por conjeturas verosímiles se deja entender que se llamaba Quijana. Pero esto importa poco a nuestro cuento: basta que en la narración dél no se salga un punto de la verdad.'

# %%
# Separamos cada palabra de la variable de texto
texto.split()

# %%
# Conteo de palabras. Expresiones regulares
import re

# %%
# \w -> [a-z][A-Z][0-9][_]
# \W -> ^[\w]
# \d -> [0-9]
# \D -> ^[0-9]
# \s -> [\t\n \r]
#caracteres no alfanuméricos
L=re.split('\W', texto) 
# Eliminar elementos reptidos
S=set(L)
S.discard('')
S
# Out:
# {'El',
#  'En',
#  'Frisaba',
#  'Mancha',
#  'Pero',
#  'Quesada',
#  'Quieren',
#  'Quijada',
#  'Quijana',
#  'Tenía',
#  'Una',
#  'a',
#  'acordarme',
#  'adarga',
#  'algo',
#  'alguna',
#  'algún',
#  'ama',
#  'amigo',
#  'antigua',
#  'astillero',
#  'así',
#  'aunque',
#  'autores',
#  'añadidura',
#  'años',
#  'basta',
#  'calzas',
#  'campo',
#  'carnero',
#  'carnes',
#  'casa',
#  'caso',
#  'caza',
#  'cincuenta',
#  'como',
#  'complexión',
#  'con',
#  'concluían',
#  'conjeturas',
#  'consumían',
#  'corredor',
#  'cuarenta',
#  'cuento',
#  'cuyo',
#  'de',
#  'decir',
#  'deja',
#  'della',
#  'deste',
#  'diferencia',
#  'domingos',
#  'duelos',
#  'dél',
#  'días',
#  'edad',
#  'el',
#  'en',
#  'enjuto',
#  'ensillaba',
#  'entender',
#  'entresemana',
#  'era',
#  'escriben',
#  'esto',
#  'fiestas',
#  'fino',
#  'flaco',
#  'galgo',
#  'gran',
#  'ha',
#  'hacienda',
#  'hay',
#  'hidalgo',
#  'honraba',
#  'importa',
#  'la',
#  'lantejas',
#  'lanza',
#  'las',
#  'llamaba',
#  'llegaba',
#  'lo',
#  'los',
#  'lugar',
#  'madrugador',
#  'mesmo',
#  'mozo',
#  'mucho',
#  'más',
#  'narración',
#  'no',
#  'noches',
#  'nombre',
#  'nuestro',
#  'o',
#  'olla',
#  'palomino',
#  'pantuflos',
#  'para',
#  'partes',
#  'pasaba',
#  'plaza',
#  'poco',
#  'podadera',
#  'por',
#  'punto',
#  'que',
#  'quebrantos',
#  'quiero',
#  'recia',
#  'resto',
#  'rocín',
#  'rocón',
#  'rostro',
#  'salga',
#  'salpicón',
#  'sayo',
#  'se',
#  'seco',
#  'sobrenombre',
#  'sobrina',
#  'su',
#  'sus',
#  'sábados',
#  'tenía',
#  'tiempo',
#  'tomaba',
#  'tres',
#  'un',
#  'una',
#  'vaca',
#  'veinte',
#  'velarte',
#  'vellorí',
#  'velludo',
#  'verdad',
#  'verosímiles',
#  'viernes',
#  'vivía',
#  'y'}

# %%
# lista de palabras que cumplan expresión regular. E o e concatenada con n
res1=re.findall('[Ee]n',texto)
# contar apariciones
len(res1)
# Out:
# 21

# %%
# lista de palabras que cumplan expresión regular. E o e concatenada con n, ignorando mayúsculas o minúsculas
res1=re.findall('en',texto,flags=re.I)
# contar apariciones
len(res1)
# Out:
# 21

# %%
# Buscamos las palabras no repetidas del set en la variable de texto para poderlas contar
d = {}
for palabra in S:
  d[palabra] = len(re.findall(palabra,texto,flags=re.I))
df = pd.DataFrame(d.items())
# Out:
#            0  1
# 0      resto  1
# 1       casa  1
# 2      tenía  2
# 3      mucho  1
# 4    viernes  1
# ..       ... ..
# 136   duelos  1
# 137   partes  1
# 138  fiestas  1
# 139     tres  2
# 140      por  2
#
# [141 rows x 2 columns]

# %% [markdown]
# # Archivos excel

# %%
# A partir de la función
pd.read_excel(ruta+'API_SI.POV.DDAY_DS2_en_excel_v2_1930012.xls')
# Out:
#            Data Source World Development Indicators  \
# 0    Last Updated Date          2020-12-16 00:00:00
# 1                  NaN                          NaN
# 2         Country Name                 Country Code
# 3                Aruba                          ABW
# 4          Afghanistan                          AFG
# ..                 ...                          ...
# 262             Kosovo                          XKX
# 263        Yemen, Rep.                          YEM
# 264       South Africa                          ZAF
# 265             Zambia                          ZMB
# 266           Zimbabwe                          ZWE
#
#                                             Unnamed: 2      Unnamed: 3  \
# 0                                                  NaN             NaN
# 1                                                  NaN             NaN
# 2                                       Indicator Name  Indicator Code
# 3    Poverty headcount ratio at $1.90 a day (2011 P...     SI.POV.DDAY
# 4    Poverty headcount ratio at $1.90 a day (2011 P...     SI.POV.DDAY
# ..                                                 ...             ...
# 262  Poverty headcount ratio at $1.90 a day (2011 P...     SI.POV.DDAY
# 263  Poverty headcount ratio at $1.90 a day (2011 P...     SI.POV.DDAY
# 264  Poverty headcount ratio at $1.90 a day (2011 P...     SI.POV.DDAY
# 265  Poverty headcount ratio at $1.90 a day (2011 P...     SI.POV.DDAY
# 266  Poverty headcount ratio at $1.90 a day (2011 P...     SI.POV.DDAY
#
#      Unnamed: 4  Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  \
# 0           NaN         NaN         NaN         NaN         NaN         NaN
# 1           NaN         NaN         NaN         NaN         NaN         NaN
# 2        1960.0      1961.0      1962.0      1963.0      1964.0      1965.0
# 3           NaN         NaN         NaN         NaN         NaN         NaN
# 4           NaN         NaN         NaN         NaN         NaN         NaN
# ..          ...         ...         ...         ...         ...         ...
# 262         NaN         NaN         NaN         NaN         NaN         NaN
# 263         NaN         NaN         NaN         NaN         NaN         NaN
# 264         NaN         NaN         NaN         NaN         NaN         NaN
# 265         NaN         NaN         NaN         NaN         NaN         NaN
# 266         NaN         NaN         NaN         NaN         NaN         NaN
#
#      ...  Unnamed: 55  Unnamed: 56  Unnamed: 57  Unnamed: 58  Unnamed: 59  \
# 0    ...          NaN          NaN          NaN          NaN          NaN
# 1    ...          NaN          NaN          NaN          NaN          NaN
# 2    ...       2011.0       2012.0       2013.0       2014.0       2015.0
# 3    ...          NaN          NaN          NaN          NaN          NaN
# 4    ...          NaN          NaN          NaN          NaN          NaN
# ..   ...          ...          ...          ...          ...          ...
# 262  ...          1.7          0.6          0.3          1.0          0.7
# 263  ...          NaN          NaN          NaN         18.3          NaN
# 264  ...          NaN          NaN          NaN         18.7          NaN
# 265  ...          NaN          NaN          NaN          NaN         58.7
# 266  ...         21.4          NaN          NaN          NaN          NaN
#
#      Unnamed: 60  Unnamed: 61  Unnamed: 62  Unnamed: 63  Unnamed: 64
# 0            NaN          NaN          NaN          NaN          NaN
# 1            NaN          NaN          NaN          NaN          NaN
# 2         2016.0       2017.0       2018.0       2019.0       2020.0
# 3            NaN          NaN          NaN          NaN          NaN
# 4            NaN          NaN          NaN          NaN          NaN
# ..           ...          ...          ...          ...          ...
# 262          0.8          0.4          NaN          NaN          NaN
# 263          NaN          NaN          NaN          NaN          NaN
# 264          NaN          NaN          NaN          NaN          NaN
# 265          NaN          NaN          NaN          NaN          NaN
# 266          NaN         33.9          NaN          NaN          NaN
#
# [267 rows x 65 columns]

# %%
# Importamos la clase ExcelFile
from pandas import ExcelFile

# %%
# A partir de la clase
obj=ExcelFile(ruta+'API_SI.POV.DDAY_DS2_en_excel_v2_1930012.xls')
obj.parse()
# Out:
#            Data Source World Development Indicators  \
# 0    Last Updated Date          2020-12-16 00:00:00
# 1                  NaN                          NaN
# 2         Country Name                 Country Code
# 3                Aruba                          ABW
# 4          Afghanistan                          AFG
# ..                 ...                          ...
# 262             Kosovo                          XKX
# 263        Yemen, Rep.                          YEM
# 264       South Africa                          ZAF
# 265             Zambia                          ZMB
# 266           Zimbabwe                          ZWE
#
#                                             Unnamed: 2      Unnamed: 3  \
# 0                                                  NaN             NaN
# 1                                                  NaN             NaN
# 2                                       Indicator Name  Indicator Code
# 3    Poverty headcount ratio at $1.90 a day (2011 P...     SI.POV.DDAY
# 4    Poverty headcount ratio at $1.90 a day (2011 P...     SI.POV.DDAY
# ..                                                 ...             ...
# 262  Poverty headcount ratio at $1.90 a day (2011 P...     SI.POV.DDAY
# 263  Poverty headcount ratio at $1.90 a day (2011 P...     SI.POV.DDAY
# 264  Poverty headcount ratio at $1.90 a day (2011 P...     SI.POV.DDAY
# 265  Poverty headcount ratio at $1.90 a day (2011 P...     SI.POV.DDAY
# 266  Poverty headcount ratio at $1.90 a day (2011 P...     SI.POV.DDAY
#
#      Unnamed: 4  Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  \
# 0           NaN         NaN         NaN         NaN         NaN         NaN
# 1           NaN         NaN         NaN         NaN         NaN         NaN
# 2        1960.0      1961.0      1962.0      1963.0      1964.0      1965.0
# 3           NaN         NaN         NaN         NaN         NaN         NaN
# 4           NaN         NaN         NaN         NaN         NaN         NaN
# ..          ...         ...         ...         ...         ...         ...
# 262         NaN         NaN         NaN         NaN         NaN         NaN
# 263         NaN         NaN         NaN         NaN         NaN         NaN
# 264         NaN         NaN         NaN         NaN         NaN         NaN
# 265         NaN         NaN         NaN         NaN         NaN         NaN
# 266         NaN         NaN         NaN         NaN         NaN         NaN
#
#      ...  Unnamed: 55  Unnamed: 56  Unnamed: 57  Unnamed: 58  Unnamed: 59  \
# 0    ...          NaN          NaN          NaN          NaN          NaN
# 1    ...          NaN          NaN          NaN          NaN          NaN
# 2    ...       2011.0       2012.0       2013.0       2014.0       2015.0
# 3    ...          NaN          NaN          NaN          NaN          NaN
# 4    ...          NaN          NaN          NaN          NaN          NaN
# ..   ...          ...          ...          ...          ...          ...
# 262  ...          1.7          0.6          0.3          1.0          0.7
# 263  ...          NaN          NaN          NaN         18.3          NaN
# 264  ...          NaN          NaN          NaN         18.7          NaN
# 265  ...          NaN          NaN          NaN          NaN         58.7
# 266  ...         21.4          NaN          NaN          NaN          NaN
#
#      Unnamed: 60  Unnamed: 61  Unnamed: 62  Unnamed: 63  Unnamed: 64
# 0            NaN          NaN          NaN          NaN          NaN
# 1            NaN          NaN          NaN          NaN          NaN
# 2         2016.0       2017.0       2018.0       2019.0       2020.0
# 3            NaN          NaN          NaN          NaN          NaN
# 4            NaN          NaN          NaN          NaN          NaN
# ..           ...          ...          ...          ...          ...
# 262          0.8          0.4          NaN          NaN          NaN
# 263          NaN          NaN          NaN          NaN          NaN
# 264          NaN          NaN          NaN          NaN          NaN
# 265          NaN          NaN          NaN          NaN          NaN
# 266          NaN         33.9          NaN          NaN          NaN
#
# [267 rows x 65 columns]

# %% [markdown]
# # Archivos JSON

# %%
pd.read_json?

# %%
pd.read_json(ruta+'data.json',orient='split')
# Out:
#           _id                                         categories  isActive  \
# 0  OzE5vaa3p7  [{'__type': 'Pointer', 'className': 'Category'...      True
# 1  ENPCL8ph1p  [{'__type': 'Pointer', 'className': 'Category'...      True
#
#                                             imageUrl        barcode  isFmcg  \
# 0  https://firebasestorage.googleapis.com/v0/b/sh...  8908001921015    True
# 1  https://firebasestorage.googleapis.com/v0/b/ki...  8901725181222    True
#
#                             itemName  mrp                      _created_at  \
# 0              Anil puttu flour 500g   58 2016-10-02 13:49:03.281000+00:00
# 1  Yippee Magic Masala Noodles, 70 G   12 2016-10-02 13:49:03.284000+00:00
#
#                        _updated_at
# 0 2017-02-22 08:48:09.548000+00:00
# 1 2017-02-22 08:48:09.074000+00:00

# %%
# _ es lo que tiene en memoria al final, lo último ejecutado. Accedemos al diccionario en la key categories
_['categories'][0]
# Out:
# [{'__type': 'Pointer', 'className': 'Category', 'objectId': 'nebCwWd2Fr'}]

# %% [markdown]
# # Archivos XML

# %%
import xml.etree.ElementTree as ET

# %%
archivo=ET.parse(ruta+'tabla_1.xml')
#Extraer estructura
raiz=archivo.getroot()

# %%
for nodo in raiz:
  print("=====================Nodo=================================")
  print(f"tag: {nodo.tag},attrib: {nodo.attrib['name']},text: {nodo.text}")
  print("=====================Sub nodos=================================")
  for subnodo in nodo:
    print(f"tag: {subnodo.tag},attrib: {subnodo.attrib},text: {subnodo.text}")
# Out:
# =====================Nodo=================================
# tag: country,attrib: Liechtenstein,text:
#
# =====================Sub nodos=================================
# tag: rank,attrib: {},text: 1
# tag: year,attrib: {},text: 2008
# tag: gdppc,attrib: {},text: 141100
# =====================Nodo=================================
# tag: country,attrib: Singapore,text:
#
# =====================Sub nodos=================================
# tag: rank,attrib: {},text: 4
# tag: year,attrib: {},text: 2011
# tag: gdppc,attrib: {},text: 59900
# =====================Nodo=================================
# tag: country,attrib: Panama,text:
#
# =====================Sub nodos=================================
# tag: rank,attrib: {},text: 68
# tag: year,attrib: {},text: 2011
# tag: gdppc,attrib: {},text: 13600

# %%
data = []
for nodo in raiz:
  country_data = {}
  country_data[nodo.tag] = nodo.attrib['name']
  for subnodo in nodo:
    country_data[subnodo.tag] = subnodo.text
  data.append(country_data)

  df = pd.DataFrame(data)
  print(df)
# Out:
#          country rank  year   gdppc
# 0  Liechtenstein    1  2008  141100
#          country rank  year   gdppc
# 0  Liechtenstein    1  2008  141100
# 1      Singapore    4  2011   59900
#          country rank  year   gdppc
# 0  Liechtenstein    1  2008  141100
# 1      Singapore    4  2011   59900
# 2         Panama   68  2011   13600

# %%
tabla_2 = ET.parse(ruta+'tabla_2.xml')
#Extraer estructura
raiz=tabla_2 =tabla_2.getroot()
print(raiz)
# Out:
# <Element 'author' at 0x7fc821f4b450>

# %%
for nodo in raiz:
  print(nodo.tag)
  for subnodo in nodo:
    print(f"tag: {subnodo.tag},attrib: {subnodo.attrib},text: {subnodo.text}")
# Out:
# documents
# tag: document,attrib: {'KEY': 'e95a9a6c790ecb95e46cf15bee517651', 'web': 'www.ubm/doc004.com'},text: Nevertheless, high and based on experience, fluctuating throughput levels contradict high reliability.
#
#
# tag: document,attrib: {'KEY': 'bc360cfbafc39970587547215162f0db', 'web': 'www.ubm/doc006.com'},text: As long as the production is not conducted on the basis of concrete customer orders, the companies objectives
#
#
# tag: document,attrib: {'KEY': '19e71144c50a8b9160b3f0955e906fce', 'web': 'www.ubm/doc005.com'},text: Many companies today, in different fields of operations and sizes, have access to a vast amount of data which was not available only a couple of years ago.
#
#
# tag: document,attrib: {'KEY': '21d4af9021a174f61b884606c74d9e42', 'web': 'www.ubm/doc002.com'},text: A famous example of a successful prediction is by the German astronomer Johann Gottfried Galle
#
#
# tag: document,attrib: {'KEY': '28a45eb2460899763d709ca00ddbb665', 'web': 'www.ubm/doc001.com'},text: A more recent example of the same kind is the prediction of the Higgs boson by Francois Englert and Peter Higgs

# %%
d_list = []
for nodo in raiz:
  for subnodo in nodo:
    d = {subnodo.tag:subnodo.text}
    for k in subnodo.attrib: # subnodo.attrib.keys() # subnodo.attrib.items() -> Regresa key y value
      d[k]=subnodo.attrib[k]
    d_list.append(d)
print(pd.DataFrame(d_list))
# Out:
#                                             document  \
# 0  Nevertheless, high and based on experience, fl...
# 1  As long as the production is not conducted on ...
# 2  Many companies today, in different fields of o...
# 3  A famous example of a successful prediction is...
# 4  A more recent example of the same kind is the ...
#
#                                 KEY                 web
# 0  e95a9a6c790ecb95e46cf15bee517651  www.ubm/doc004.com
# 1  bc360cfbafc39970587547215162f0db  www.ubm/doc006.com
# 2  19e71144c50a8b9160b3f0955e906fce  www.ubm/doc005.com
# 3  21d4af9021a174f61b884606c74d9e42  www.ubm/doc002.com
# 4  28a45eb2460899763d709ca00ddbb665  www.ubm/doc001.com

# %% [markdown]
# ---

# %%
archivo='IFC-Subscriptions-and-Voting-Power-of-Member-Count.xml'
file=ET.parse(ruta+archivo)
root=file.getroot()
# Out:
# {}

# %%
sub_1 = 1
for nodo in root:
  print(f"======subnodo {sub_1}======")
  sub_2 = 1
  for subnodo_1 in nodo:
    print(f"tag: {subnodo_1.tag},attrib: {subnodo_1.attrib},text: {subnodo_1.text}")
    print(f"======subnodo {sub_1}.{sub_2}======")
    sub_2+=1
    for subnodo_2 in subnodo_1:
      print(f"tag: {subnodo_2.tag},attrib: {subnodo_2.attrib},text: {subnodo_2.text}")
  sub_1+=1
# Out:
# ======subnodo 1======
# tag: row,attrib: {'_id': 'row-y44j~at3a-b2ir', '_uuid': '00000000-0000-0000-0100-063657E78388', '_position': '0', '_address': 'https://finances.worldbank.org/resource/gsdw-avpz/row-y44j~at3a-b2ir'},text:
#
# ======subnodo 1.1======
# tag: member,attrib: {},text: Afghanistan
# tag: amount_thousands_of_usd,attrib: {},text: 1727
# tag: percent_of_total_amount,attrib: {},text: 0.01
# tag: number_of_votes,attrib: {},text: 8326
# tag: percent_of_total_votes,attrib: {},text: 0.04
# tag: as_of_date,attrib: {},text: 2021-08-06T00:00:00
# tag: row,attrib: {'_id': 'row-cgqt~xxg3~xehh', '_uuid': '00000000-0000-0000-028B-9164C4785E6F', '_position': '0', '_address': 'https://finances.worldbank.org/resource/gsdw-avpz/row-cgqt~xxg3~xehh'},text:
#
# ======subnodo 1.2======
# tag: member,attrib: {},text: Albania
# tag: amount_thousands_of_usd,attrib: {},text: 9927
# tag: percent_of_total_amount,attrib: {},text: 0.05
# tag: number_of_votes,attrib: {},text: 16526
# tag: percent_of_total_votes,attrib: {},text: 0.08
# tag: as_of_date,attrib: {},text: 2021-08-06T00:00:00
# tag: row,attrib: {'_id': 'row-q7xr_qk5p_hqh3', '_uuid': '00000000-0000-0000-E37B-CAECEC3A0C26', '_position': '0', '_address': 'https://finances.worldbank.org/resource/gsdw-avpz/row-q7xr_qk5p_hqh3'},text:
#
# ======subnodo 1.3======
# tag: member,attrib: {},text: Algeria
# tag: amount_thousands_of_usd,attrib: {},text: 51116
# tag: percent_of_total_amount,attrib: {},text: 0.25
# tag: number_of_votes,attrib: {},text: 57715
# tag: percent_of_total_votes,attrib: {},text: 0.26
# tag: as_of_date,attrib: {},text: 2021-08-06T00:00:00
# tag: row,attrib: {'_id': 'row-u2xu-enky.kggg', '_uuid': '00000000-0000-0000-5E03-D3BA6F640E74', '_position': '0', '_address': 'https://finances.worldbank.org/resource/gsdw-avpz/row-u2xu-enky.kggg'},text:
#
# ======subnodo 1.4======
# tag: member,attrib: {},text: Angola
# tag: amount_thousands_of_usd,attrib: {},text: 11292
# tag: percent_of_total_amount,attrib: {},text: 0.05
# tag: number_of_votes,attrib: {},text: 17891
# tag: percent_of_total_votes,attrib: {},text: 0.08
# tag: as_of_date,attrib: {},text: 2021-08-06T00:00:00
# tag: row,attrib: {'_id': 'row-j7ts~ti34_3pcy', '_uuid': '00000000-0000-0000-2FA7-DDD7B7C43943', '_position': '0', '_address': 'https://finances.worldbank.org/resource/gsdw-avpz/row-j7ts~ti34_3pcy'},text:
#
# ======subnodo 1.5======
# tag: member,attrib: {},text: Antigua and Barbuda
# tag: amount_thousands_of_usd,attrib: {},text: 99
# tag: percent_of_total_amount,attrib: {},text: 0.00
# tag: number_of_votes,attrib: {},text: 6698
# tag: percent_of_total_votes,attrib: {},text: 0.03
# tag: as_of_date,attrib: {},text: 2021-08-06T00:00:00
# tag: row,attrib: {'_id': 'row-geqr.hf5b~pme8', '_uuid': '00000000-0000-0000-7BA7-A38C9799858F', '_position': '0', '_address': 'https://finances.worldbank.org/resource/gsdw-avpz/row-geqr.hf5b~pme8'},text:
#
# ======subnodo 1.6======
# tag: member,attrib: {},text: Argentina
# tag: amount_thousands_of_usd,attrib: {},text: 323320
# tag: percent_of_total_amount,attrib: {},text: 1.56
# tag: number_of_votes,attrib: {},text: 329919
# tag: percent_of_total_votes,attrib: {},text: 1.50
# tag: as_of_date,attrib: {},text: 2021-08-06T00:00:00
# tag: row,attrib: {'_id': 'row-vct9-gbrd-kdsk', '_uuid': '00000000-0000-0000-6EAF-7A4ED7CD8724', '_position': '0', '_address': 'https://finances.worldbank.org/resource/gsdw-avpz/row-vct9-gbrd-kdsk'},text:
#
# ======subnodo 1.7======
# tag: member,attrib: {},text: Armenia
# tag: amount_thousands_of_usd,attrib: {},text: 7564
# tag: percent_of_total_amount,attrib: {},text: 0.04
# tag: number_of_votes,attrib: {},text: 14163
# tag: percent_of_total_votes,attrib: {},text: 0.06
# tag: as_of_date,attrib: {},text: 2021-08-06T00:00:00
# tag: row,attrib: {'_id': 'row-6tcz.psxe~p4jx', '_uuid': '00000000-0000-0000-F0C9-F90D050B348E', '_position': '0', '_address': 'https://finances.worldbank.org/resource/gsdw-avpz/row-6tcz.psxe~p4jx'},text:
#
# ======subnodo 1.8======
# tag: member,attrib: {},text: Australia
# tag: amount_thousands_of_usd,attrib: {},text: 401814
# tag: percent_of_total_amount,attrib: {},text: 1.93
# tag: number_of_votes,attrib: {},text: 408413
# tag: percent_of_total_votes,attrib: {},text: 1.86
# tag: as_of_date,attrib: {},text: 2021-08-06T00:00:00
# tag: row,attrib: {'_id': 'row-phnu-yhin.6pnb', '_uuid': '00000000-0000-0000-417A-87B21F7C5B8C', '_position': '0', '_address': 'https://finances.worldbank.org/resource/gsdw-avpz/row-phnu-yhin.6pnb'},text:
#
# ======subnodo 1.9======
# tag: member,attrib: {},text: Austria
# tag: amount_thousands_of_usd,attrib: {},text: 161192
# tag: percent_of_total_amount,attrib: {},text: 0.78
# tag: number_of_votes,attrib: {},text: 167791
# tag: percent_of_total_votes,attrib: {},text: 0.76
# tag: as_of_date,attrib: {},text: 2021-08-06T00:00:00
# tag: row,attrib: {'_id': 'row-iysh_uwu8-mbrd', '_uuid': '00000000-0000-0000-1906-7E92EA2CCF37', '_position': '0', '_address': 'https://finances.worldbank.org/resource/gsdw-avpz/row-iysh_uwu8-mbrd'},text:
#
# ======subnodo 1.10======
# tag: member,attrib: {},text: Azerbaijan
# tag: amount_thousands_of_usd,attrib: {},text: 18047
# tag: percent_of_total_amount,attrib: {},text: 0.09
# tag: number_of_votes,attrib: {},text: 24646
# tag: percent_of_total_votes,attrib: {},text: 0.11
# tag: as_of_date,attrib: {},text: 2021-08-06T00:00:00
# tag: row,attrib: {'_id': 'row-scnb~mk4h~atcb', '_uuid': '00000000-0000-0000-59DE-84BD2BD2B4F1', '_position': '0', '_address': 'https://finances.worldbank.org/resource/gsdw-avpz/row-scnb~mk4h~atcb'},text:
#
# ======subnodo 1.11======
# tag: member,attrib: {},text: Bahamas, The
# tag: amount_thousands_of_usd,attrib: {},text: 2554
# tag: percent_of_total_amount,attrib: {},text: 0.01
# tag: number_of_votes,attrib: {},text: 9153
# tag: percent_of_total_votes,attrib: {},text: 0.04
# tag: as_of_date,attrib: {},text: 2021-08-06T00:00:00
# tag: row,attrib: {'_id': 'row-eyn7-p3d5_itvt', '_uuid': '00000000-0000-0000-36D6-7172B1E2CB50', '_position': '0', '_address': 'https://finances.worldbank.org/resource/gsdw-avpz/row-eyn7-p3d5_itvt'},text:
#
# ======subnodo 1.12======
# tag: member,attrib: {},text: Bahrain
# tag: amount_thousands_of_usd,attrib: {},text: 13313
# tag: percent_of_total_amount,attrib: {},text: 0.06
# tag: number_of_votes,attrib: {},text: 19912
# tag: percent_of_total_votes,attrib: {},text: 0.09
# tag: as_of_date,attrib: {},text: 2021-08-06T00:00:00
# tag: row,attrib: {'_id': 'row-5xhz.y8aw~7cxx', '_uuid': '00000000-0000-0000-875E-BF9163FCCF6A', '_position': '0', '_address': 'https://finances.worldbank.org/resource/gsdw-avpz/row-5xhz.y8aw~7cxx'},text:
#
# ======subnodo 1.13======
# tag: member,attrib: {},text: Bangladesh
# tag: amount_thousands_of_usd,attrib: {},text: 73440
# tag: percent_of_total_amount,attrib: {},text: 0.35
# tag: number_of_votes,attrib: {},text: 80039
# tag: percent_of_total_votes,attrib: {},text: 0.36
# tag: as_of_date,attrib: {},text: 2021-08-06T00:00:00
# tag: row,attrib: {'_id': 'row-n3r2-n8gv.pxn6', '_uuid': '00000000-0000-0000-EF34-D5E63E4E2957', '_position': '0', '_address': 'https://finances.worldbank.org/resource/gsdw-avpz/row-n3r2-n8gv.pxn6'},text:
#
# ======subnodo 1.14======
# tag: member,attrib: {},text: Barbados
# tag: amount_thousands_of_usd,attrib: {},text: 2752
# tag: percent_of_total_amount,attrib: {},text: 0.01
# tag: number_of_votes,attrib: {},text: 9351
# tag: percent_of_total_votes,attrib: {},text: 0.04
# tag: as_of_date,attrib: {},text: 2021-08-06T00:00:00
# tag: row,attrib: {'_id': 'row-z3fe~yh2x.bb2p', '_uuid': '00000000-0000-0000-E432-4A628F933E8E', '_position': '0', '_address': 'https://finances.worldbank.org/resource/gsdw-avpz/row-z3fe~yh2x.bb2p'},text:
#
# ======subnodo 1.15======
# tag: member,attrib: {},text: Belarus
# tag: amount_thousands_of_usd,attrib: {},text: 40159
# tag: percent_of_total_amount,attrib: {},text: 0.19
# tag: number_of_votes,attrib: {},text: 46758
# tag: percent_of_total_votes,attrib: {},text: 0.21
# tag: as_of_date,attrib: {},text: 2021-08-06T00:00:00
# tag: row,attrib: {'_id': 'row-2mi8-vkvt-tqge', '_uuid': '00000000-0000-0000-0A2F-917771F88F2B', '_position': '0', '_address': 'https://finances.worldbank.org/resource/gsdw-avpz/row-2mi8-vkvt-tqge'},text:
#
# ======subnodo 1.16======
# tag: member,attrib: {},text: Belgium
# tag: amount_thousands_of_usd,attrib: {},text: 385880
# tag: percent_of_total_amount,attrib: {},text: 1.86
# tag: number_of_votes,attrib: {},text: 392479
# tag: percent_of_total_votes,attrib: {},text: 1.78
# tag: as_of_date,attrib: {},text: 2021-08-06T00:00:00
# tag: row,attrib: {'_id': 'row-wp9x_9cwt-y9zb', '_uuid': '00000000-0000-0000-47BB-629CA09F772C', '_position': '0', '_address': 'https://finances.worldbank.org/resource/gsdw-avpz/row-wp9x_9cwt-y9zb'},text:
#
# ======subnodo 1.17======
# tag: member,attrib: {},text: Belize
# tag: amount_thousands_of_usd,attrib: {},text: 770
# tag: percent_of_total_amount,attrib: {},text: 0.00
# tag: number_of_votes,attrib: {},text: 7369
# tag: percent_of_total_votes,attrib: {},text: 0.03
# tag: as_of_date,attrib: {},text: 2021-08-06T00:00:00
# tag: row,attrib: {'_id': 'row-bsru.bbwf-ce4z', '_uuid': '00000000-0000-0000-6248-BB06A9602EDE', '_position': '0', '_address': 'https://finances.worldbank.org/resource/gsdw-avpz/row-bsru.bbwf-ce4z'},text:
#
# ======subnodo 1.18======
# tag: member,attrib: {},text: Benin
# tag: amount_thousands_of_usd,attrib: {},text: 907
# tag: percent_of_total_amount,attrib: {},text: 0.00
# tag: number_of_votes,attrib: {},text: 7506
# tag: percent_of_total_votes,attrib: {},text: 0.03
# tag: as_of_date,attrib: {},text: 2021-08-06T00:00:00
# tag: row,attrib: {'_id': 'row-v26i.tv2s_8daq', '_uuid': '00000000-0000-0000-A8DE-812509DB753E', '_position': '0', '_address': 'https://finances.worldbank.org/resource/gsdw-avpz/row-v26i.tv2s_8daq'},text:
#
# ======subnodo 1.19======
# tag: member,attrib: {},text: Bhutan
# tag: amount_thousands_of_usd,attrib: {},text: 5490
# tag: percent_of_total_amount,attrib: {},text: 0.03
# tag: number_of_votes,attrib: {},text: 12089
# tag: percent_of_total_votes,attrib: {},text: 0.05
# tag: as_of_date,attrib: {},text: 2021-08-06T00:00:00
# tag: row,attrib: {'_id': 'row-d5pv_crx5-fm6f', '_uuid': '00000000-0000-0000-69F9-2DC06374EF0A', '_position': '0', '_address': 'https://finances.worldbank.org/resource/gsdw-avpz/row-d5pv_crx5-fm6f'},text:
#
# ======subnodo 1.20======
# tag: member,attrib: {},text: Bolivia
# tag: amount_thousands_of_usd,attrib: {},text: 14502
# tag: percent_of_total_amount,attrib: {},text: 0.07
# tag: number_of_votes,attrib: {},text: 21101
# tag: percent_of_total_votes,attrib: {},text: 0.10
# tag: as_of_date,attrib: {},text: 2021-08-06T00:00:00
# tag: row,attrib: {'_id': 'row-ufhx.da26-85rt', '_uuid': '00000000-0000-0000-7C74-E38640986EB9', '_position': '0', '_address': 'https://finances.worldbank.org/resource/gsdw-avpz/row-ufhx.da26-85rt'},text:
#
# ======subnodo 1.21======
# tag: member,attrib: {},text: Bosnia and Herzegovina
# tag: amount_thousands_of_usd,attrib: {},text: 5921
# tag: percent_of_total_amount,attrib: {},text: 0.03
# tag: number_of_votes,attrib: {},text: 12520
# tag: percent_of_total_votes,attrib: {},text: 0.06
# tag: as_of_date,attrib: {},text: 2021-08-06T00:00:00
# tag: row,attrib: {'_id': 'row-zgfu.kw8d.8vwb', '_uuid': '00000000-0000-0000-55E7-0776E0377EF5', '_position': '0', '_address': 'https://finances.worldbank.org/resource/gsdw-avpz/row-zgfu.kw8d.8vwb'},text:
#
# ======subnodo 1.22======
# tag: member,attrib: {},text: Botswana
# tag: amount_thousands_of_usd,attrib: {},text: 862
# tag: percent_of_total_amount,attrib: {},text: 0.00
# tag: number_of_votes,attrib: {},text: 7461
# tag: percent_of_total_votes,attrib: {},text: 0.03
# tag: as_of_date,attrib: {},text: 2021-08-06T00:00:00
# tag: row,attrib: {'_id': 'row-73fr~axud.mhv8', '_uuid': '00000000-0000-0000-AD45-ABDD1076201E', '_position': '0', '_address': 'https://finances.worldbank.org/resource/gsdw-avpz/row-73fr~axud.mhv8'},text:
#
# ======subnodo 1.23======
# tag: member,attrib: {},text: Brazil
# tag: amount_thousands_of_usd,attrib: {},text: 423812
# tag: percent_of_total_amount,attrib: {},text: 2.04
# tag: number_of_votes,attrib: {},text: 430411
# tag: percent_of_total_votes,attrib: {},text: 1.96
# tag: as_of_date,attrib: {},text: 2021-08-06T00:00:00
# tag: row,attrib: {'_id': 'row-4ymb-7kxa_sj6r', '_uuid': '00000000-0000-0000-7B78-0C506B6CC088', '_position': '0', '_address': 'https://finances.worldbank.org/resource/gsdw-avpz/row-4ymb-7kxa_sj6r'},text:
#
# ======subnodo 1.24======
# tag: member,attrib: {},text: Bulgaria
# tag: amount_thousands_of_usd,attrib: {},text: 37620
# tag: percent_of_total_amount,attrib: {},text: 0.18
# tag: number_of_votes,attrib: {},text: 44219
# tag: percent_of_total_votes,attrib: {},text: 0.20
# tag: as_of_date,attrib: {},text: 2021-08-06T00:00:00
# tag: row,attrib: {'_id': 'row-hpiq.kk3z_uk8d', '_uuid': '00000000-0000-0000-1DFF-B1E7BC4A0A1D', '_position': '0', '_address': 'https://finances.worldbank.org/resource/gsdw-avpz/row-hpiq.kk3z_uk8d'},text:
#
# ======subnodo 1.25======
# tag: member,attrib: {},text: Burkina Faso
# tag: amount_thousands_of_usd,attrib: {},text: 6374
# tag: percent_of_total_amount,attrib: {},text: 0.03
# tag: number_of_votes,attrib: {},text: 12973
# tag: percent_of_total_votes,attrib: {},text: 0.06
# tag: as_of_date,attrib: {},text: 2021-08-06T00:00:00
# tag: row,attrib: {'_id': 'row-zkk3-ftyx_gura', '_uuid': '00000000-0000-0000-E564-806375DE2E2C', '_position': '0', '_address': 'https://finances.worldbank.org/resource/gsdw-avpz/row-zkk3-ftyx_gura'},text:
#
# ======subnodo 1.26======
# tag: member,attrib: {},text: Burundi
# tag: amount_thousands_of_usd,attrib: {},text: 762
# tag: percent_of_total_amount,attrib: {},text: 0.00
# tag: number_of_votes,attrib: {},text: 7361
# tag: percent_of_total_votes,attrib: {},text: 0.03
# tag: as_of_date,attrib: {},text: 2021-08-06T00:00:00
# tag: row,attrib: {'_id': 'row-xsde-q2r3~psrk', '_uuid': '00000000-0000-0000-F129-A2A9F6F5A1D3', '_position': '0', '_address': 'https://finances.worldbank.org/resource/gsdw-avpz/row-xsde-q2r3~psrk'},text:
#
# ======subnodo 1.27======
# tag: member,attrib: {},text: CABO VERDE
# tag: amount_thousands_of_usd,attrib: {},text: 114
# tag: percent_of_total_amount,attrib: {},text: 0.00
# tag: number_of_votes,attrib: {},text: 6713
# tag: percent_of_total_votes,attrib: {},text: 0.03
# tag: as_of_date,attrib: {},text: 2021-08-06T00:00:00
# tag: row,attrib: {'_id': 'row-stm5-kuzv-vi7a', '_uuid': '00000000-0000-0000-4219-18A62E093D4D', '_position': '0', '_address': 'https://finances.worldbank.org/resource/gsdw-avpz/row-stm5-kuzv-vi7a'},text:
#
# ======subnodo 1.28======
# tag: member,attrib: {},text: Cambodia
# tag: amount_thousands_of_usd,attrib: {},text: 2585
# tag: percent_of_total_amount,attrib: {},text: 0.01
# tag: number_of_votes,attrib: {},text: 9184
# tag: percent_of_total_votes,attrib: {},text: 0.04
# tag: as_of_date,attrib: {},text: 2021-08-06T00:00:00
# tag: row,attrib: {'_id': 'row-ycht.7a4c-4ke5', '_uuid': '00000000-0000-0000-A362-2992318BAB44', '_position': '0', '_address': 'https://finances.worldbank.org/resource/gsdw-avpz/row-ycht.7a4c-4ke5'},text:
#
# ======subnodo 1.29======
# tag: member,attrib: {},text: Cameroon
# tag: amount_thousands_of_usd,attrib: {},text: 6748
# tag: percent_of_total_amount,attrib: {},text: 0.03
# tag: number_of_votes,attrib: {},text: 13347
# tag: percent_of_total_votes,attrib: {},text: 0.06
# tag: as_of_date,attrib: {},text: 2021-08-06T00:00:00
# tag: row,attrib: {'_id': 'row-xgga.szsn-b94e', '_uuid': '00000000-0000-0000-D9BB-F2EC2DD11E0E', '_position': '0', '_address': 'https://finances.worldbank.org/resource/gsdw-avpz/row-xgga.szsn-b94e'},text:
#
# ======subnodo 1.30======
# tag: member,attrib: {},text: Canada
# tag: amount_thousands_of_usd,attrib: {},text: 620199
# tag: percent_of_total_amount,attrib: {},text: 2.99
# tag: number_of_votes,attrib: {},text: 626798
# tag: percent_of_total_votes,attrib: {},text: 2.85
# tag: as_of_date,attrib: {},text: 2021-08-06T00:00:00
# tag: row,attrib: {'_id': 'row-tpu8~fvfm-x5id', '_uuid': '00000000-0000-0000-89F0-6B7E8D3717DA', '_position': '0', '_address': 'https://finances.worldbank.org/resource/gsdw-avpz/row-tpu8~fvfm-x5id'},text:
#
# ======subnodo 1.31======
# tag: member,attrib: {},text: Central African Republic
# tag: amount_thousands_of_usd,attrib: {},text: 907
# tag: percent_of_total_amount,attrib: {},text: 0.00
# tag: number_of_votes,attrib: {},text: 7506
# tag: percent_of_total_votes,attrib: {},text: 0.03
# tag: as_of_date,attrib: {},text: 2021-08-06T00:00:00
# tag: row,attrib: {'_id': 'row-2b2v.4hsh-7tsp', '_uuid': '00000000-0000-0000-0271-ADE02734B662', '_position': '0', '_address': 'https://finances.worldbank.org/resource/gsdw-avpz/row-2b2v.4hsh-7tsp'},text:
#
# ======subnodo 1.32======
# tag: member,attrib: {},text: Chad
# tag: amount_thousands_of_usd,attrib: {},text: 10400
# tag: percent_of_total_amount,attrib: {},text: 0.05
# tag: number_of_votes,attrib: {},text: 16999
# tag: percent_of_total_votes,attrib: {},text: 0.08
# tag: as_of_date,attrib: {},text: 2021-08-06T00:00:00
# tag: row,attrib: {'_id': 'row-2v3b~ybi4_7ew2', '_uuid': '00000000-0000-0000-E241-E6B829A3A2DC', '_position': '0', '_address': 'https://finances.worldbank.org/resource/gsdw-avpz/row-2v3b~ybi4_7ew2'},text:
#
# ======subnodo 1.33======
# tag: member,attrib: {},text: Chile
# tag: amount_thousands_of_usd,attrib: {},text: 96428
# tag: percent_of_total_amount,attrib: {},text: 0.46
# tag: number_of_votes,attrib: {},text: 103027
# tag: percent_of_total_votes,attrib: {},text: 0.47
# tag: as_of_date,attrib: {},text: 2021-08-06T00:00:00
# tag: row,attrib: {'_id': 'row-c6bi~ct9y.9c4d', '_uuid': '00000000-0000-0000-873A-6B18AA78F685', '_position': '0', '_address': 'https://finances.worldbank.org/resource/gsdw-avpz/row-c6bi~ct9y.9c4d'},text:
#
# ======subnodo 1.34======
# tag: member,attrib: {},text: China
# tag: amount_thousands_of_usd,attrib: {},text: 470864
# tag: percent_of_total_amount,attrib: {},text: 2.27
# tag: number_of_votes,attrib: {},text: 477463
# tag: percent_of_total_votes,attrib: {},text: 2.17
# tag: as_of_date,attrib: {},text: 2021-08-06T00:00:00
# tag: row,attrib: {'_id': 'row-mkxt.iw8x-m6ip', '_uuid': '00000000-0000-0000-6558-5D0623BE5649', '_position': '0', '_address': 'https://finances.worldbank.org/resource/gsdw-avpz/row-mkxt.iw8x-m6ip'},text:
#
# ======subnodo 1.35======
# tag: member,attrib: {},text: Colombia
# tag: amount_thousands_of_usd,attrib: {},text: 104137
# tag: percent_of_total_amount,attrib: {},text: 0.50
# tag: number_of_votes,attrib: {},text: 110736
# tag: percent_of_total_votes,attrib: {},text: 0.50
# tag: as_of_date,attrib: {},text: 2021-08-06T00:00:00
# tag: row,attrib: {'_id': 'row-ddiz_pfz8_kvdr', '_uuid': '00000000-0000-0000-773D-D0AB05484411', '_position': '0', '_address': 'https://finances.worldbank.org/resource/gsdw-avpz/row-ddiz_pfz8_kvdr'},text:
#
# ======subnodo 1.36======
# tag: member,attrib: {},text: Comoros
# tag: amount_thousands_of_usd,attrib: {},text: 107
# tag: percent_of_total_amount,attrib: {},text: 0.00
# tag: number_of_votes,attrib: {},text: 6706
# tag: percent_of_total_votes,attrib: {},text: 0.03
# tag: as_of_date,attrib: {},text: 2021-08-06T00:00:00
# tag: row,attrib: {'_id': 'row-p2wp~3f9z.9n4s', '_uuid': '00000000-0000-0000-74D4-0895CBD6404D', '_position': '0', '_address': 'https://finances.worldbank.org/resource/gsdw-avpz/row-p2wp~3f9z.9n4s'},text:
#
# ======subnodo 1.37======
# tag: member,attrib: {},text: Congo, Democratic Republic of
# tag: amount_thousands_of_usd,attrib: {},text: 16461
# tag: percent_of_total_amount,attrib: {},text: 0.08
# tag: number_of_votes,attrib: {},text: 23060
# tag: percent_of_total_votes,attrib: {},text: 0.10
# tag: as_of_date,attrib: {},text: 2021-08-06T00:00:00
# tag: row,attrib: {'_id': 'row-tg2s.x2v7-xkaz', '_uuid': '00000000-0000-0000-C974-FBED0584B453', '_position': '0', '_address': 'https://finances.worldbank.org/resource/gsdw-avpz/row-tg2s.x2v7-xkaz'},text:
#
# ======subnodo 1.38======
# tag: member,attrib: {},text: Congo, Republic of
# tag: amount_thousands_of_usd,attrib: {},text: 999
# tag: percent_of_total_amount,attrib: {},text: 0.00
# tag: number_of_votes,attrib: {},text: 7598
# tag: percent_of_total_votes,attrib: {},text: 0.03
# tag: as_of_date,attrib: {},text: 2021-08-06T00:00:00
# tag: row,attrib: {'_id': 'row-3bpt-dke2~34t6', '_uuid': '00000000-0000-0000-C865-05C9AC41D473', '_position': '0', '_address': 'https://finances.worldbank.org/resource/gsdw-avpz/row-3bpt-dke2~34t6'},text:
#
# ======subnodo 1.39======
# tag: member,attrib: {},text: Costa Rica
# tag: amount_thousands_of_usd,attrib: {},text: 7259
# tag: percent_of_total_amount,attrib: {},text: 0.03
# tag: number_of_votes,attrib: {},text: 13858
# tag: percent_of_total_votes,attrib: {},text: 0.06
# tag: as_of_date,attrib: {},text: 2021-08-06T00:00:00
# tag: row,attrib: {'_id': 'row-n3p9.7qtq.saxj', '_uuid': '00000000-0000-0000-E4E8-2E7F7C925294', '_position': '0', '_address': 'https://finances.worldbank.org/resource/gsdw-avpz/row-n3p9.7qtq.saxj'},text:
#
# ======subnodo 1.40======
# tag: member,attrib: {},text: Cote d'Ivoire
# tag: amount_thousands_of_usd,attrib: {},text: 29443
# tag: percent_of_total_amount,attrib: {},text: 0.14
# tag: number_of_votes,attrib: {},text: 36042
# tag: percent_of_total_votes,attrib: {},text: 0.16
# tag: as_of_date,attrib: {},text: 2021-08-06T00:00:00
# tag: row,attrib: {'_id': 'row-wm44-8kgr.7wkm', '_uuid': '00000000-0000-0000-7F42-D8273C36CB7B', '_position': '0', '_address': 'https://finances.worldbank.org/resource/gsdw-avpz/row-wm44-8kgr.7wkm'},text:
#
# ======subnodo 1.41======
# tag: member,attrib: {},text: Croatia
# tag: amount_thousands_of_usd,attrib: {},text: 23384
# tag: percent_of_total_amount,attrib: {},text: 0.11
# tag: number_of_votes,attrib: {},text: 29983
# tag: percent_of_total_votes,attrib: {},text: 0.14
# tag: as_of_date,attrib: {},text: 2021-08-06T00:00:00
# tag: row,attrib: {'_id': 'row-m6x4.kdiw.69zs', '_uuid': '00000000-0000-0000-2957-4028107E2241', '_position': '0', '_address': 'https://finances.worldbank.org/resource/gsdw-avpz/row-m6x4.kdiw.69zs'},text:
#
# ======subnodo 1.42======
# tag: member,attrib: {},text: Cyprus
# tag: amount_thousands_of_usd,attrib: {},text: 16309
# tag: percent_of_total_amount,attrib: {},text: 0.08
# tag: number_of_votes,attrib: {},text: 22908
# tag: percent_of_total_votes,attrib: {},text: 0.10
# tag: as_of_date,attrib: {},text: 2021-08-06T00:00:00
# tag: row,attrib: {'_id': 'row-f6g7_7p38-dybb', '_uuid': '00000000-0000-0000-4D7E-CA71479B6D36', '_position': '0', '_address': 'https://finances.worldbank.org/resource/gsdw-avpz/row-f6g7_7p38-dybb'},text:
#
# ======subnodo 1.43======
# tag: member,attrib: {},text: Czech Republic
# tag: amount_thousands_of_usd,attrib: {},text: 79076
# tag: percent_of_total_amount,attrib: {},text: 0.38
# tag: number_of_votes,attrib: {},text: 85675
# tag: percent_of_total_votes,attrib: {},text: 0.39
# tag: as_of_date,attrib: {},text: 2021-08-06T00:00:00
# tag: row,attrib: {'_id': 'row-u2ng~t3mx_tnu8', '_uuid': '00000000-0000-0000-ABCC-34980FD6D807', '_position': '0', '_address': 'https://finances.worldbank.org/resource/gsdw-avpz/row-u2ng~t3mx_tnu8'},text:
#
# ======subnodo 1.44======
# tag: member,attrib: {},text: Denmark
# tag: amount_thousands_of_usd,attrib: {},text: 170267
# tag: percent_of_total_amount,attrib: {},text: 0.82
# tag: number_of_votes,attrib: {},text: 176866
# tag: percent_of_total_votes,attrib: {},text: 0.80
# tag: as_of_date,attrib: {},text: 2021-08-06T00:00:00
# tag: row,attrib: {'_id': 'row-kyyk_gxde.jq9b', '_uuid': '00000000-0000-0000-E2EB-2DDF316C2B08', '_position': '0', '_address': 'https://finances.worldbank.org/resource/gsdw-avpz/row-kyyk_gxde.jq9b'},text:
#
# ======subnodo 1.45======
# tag: member,attrib: {},text: Djibouti
# tag: amount_thousands_of_usd,attrib: {},text: 160
# tag: percent_of_total_amount,attrib: {},text: 0.00
# tag: number_of_votes,attrib: {},text: 6759
# tag: percent_of_total_votes,attrib: {},text: 0.03
# tag: as_of_date,attrib: {},text: 2021-08-06T00:00:00
# tag: row,attrib: {'_id': 'row-gz3e.hnc2.ymxw', '_uuid': '00000000-0000-0000-1288-F3C5A6A68C1C', '_position': '0', '_address': 'https://finances.worldbank.org/resource/gsdw-avpz/row-gz3e.hnc2.ymxw'},text:
#
# ======subnodo 1.46======
# tag: member,attrib: {},text: Dominica
# tag: amount_thousands_of_usd,attrib: {},text: 320
# tag: percent_of_total_amount,attrib: {},text: 0.00
# tag: number_of_votes,attrib: {},text: 6919
# tag: percent_of_total_votes,attrib: {},text: 0.03
# tag: as_of_date,attrib: {},text: 2021-08-06T00:00:00
# tag: row,attrib: {'_id': 'row-79zk.2amz~vmfd', '_uuid': '00000000-0000-0000-3057-0E32AE875166', '_position': '0', '_address': 'https://finances.worldbank.org/resource/gsdw-avpz/row-79zk.2amz~vmfd'},text:
#
# ======subnodo 1.47======
# tag: member,attrib: {},text: Dominican Republic
# tag: amount_thousands_of_usd,attrib: {},text: 9050
# tag: percent_of_total_amount,attrib: {},text: 0.04
# tag: number_of_votes,attrib: {},text: 15649
# tag: percent_of_total_votes,attrib: {},text: 0.07
# tag: as_of_date,attrib: {},text: 2021-08-06T00:00:00
# tag: row,attrib: {'_id': 'row-63k4.qbpc-6gbp', '_uuid': '00000000-0000-0000-4AE8-074983F41E18', '_position': '0', '_address': 'https://finances.worldbank.org/resource/gsdw-avpz/row-63k4.qbpc-6gbp'},text:
#
# ======subnodo 1.48======
# tag: member,attrib: {},text: Ecuador
# tag: amount_thousands_of_usd,attrib: {},text: 16477
# tag: percent_of_total_amount,attrib: {},text: 0.08
# tag: number_of_votes,attrib: {},text: 23076
# tag: percent_of_total_votes,attrib: {},text: 0.10
# tag: as_of_date,attrib: {},text: 2021-08-06T00:00:00
# tag: row,attrib: {'_id': 'row-9izi.fybb-gmxz', '_uuid': '00000000-0000-0000-7A24-32F1458F6D78', '_position': '0', '_address': 'https://finances.worldbank.org/resource/gsdw-avpz/row-9izi.fybb-gmxz'},text:
#
# ======subnodo 1.49======
# tag: member,attrib: {},text: Egypt, Arab Republic of
# tag: amount_thousands_of_usd,attrib: {},text: 102017
# tag: percent_of_total_amount,attrib: {},text: 0.49
# tag: number_of_votes,attrib: {},text: 108616
# tag: percent_of_total_votes,attrib: {},text: 0.49
# tag: as_of_date,attrib: {},text: 2021-08-06T00:00:00
# tag: row,attrib: {'_id': 'row-rxn5_w92m~pdhf', '_uuid': '00000000-0000-0000-F246-3CF940C3ABD8', '_position': '0', '_address': 'https://finances.worldbank.org/resource/gsdw-avpz/row-rxn5_w92m~pdhf'},text:
#
# ======subnodo 1.50======
# tag: member,attrib: {},text: El Salvador
# tag: amount_thousands_of_usd,attrib: {},text: 221
# tag: percent_of_total_amount,attrib: {},text: 0.00
# tag: number_of_votes,attrib: {},text: 6820
# tag: percent_of_total_votes,attrib: {},text: 0.03
# tag: as_of_date,attrib: {},text: 2021-08-06T00:00:00
# tag: row,attrib: {'_id': 'row-pjuk-v9s8.y8vv', '_uuid': '00000000-0000-0000-8A7D-1F2E86537DE4', '_position': '0', '_address': 'https://finances.worldbank.org/resource/gsdw-avpz/row-pjuk-v9s8.y8vv'},text:
#
# ======subnodo 1.51======
# tag: member,attrib: {},text: Equatorial Guinea
# tag: amount_thousands_of_usd,attrib: {},text: 328
# tag: percent_of_total_amount,attrib: {},text: 0.00
# tag: number_of_votes,attrib: {},text: 6927
# tag: percent_of_total_votes,attrib: {},text: 0.03
# tag: as_of_date,attrib: {},text: 2021-08-06T00:00:00
# tag: row,attrib: {'_id': 'row-7rsr.82wk-dvyy', '_uuid': '00000000-0000-0000-2A52-A234F7812BAD', '_position': '0', '_address': 'https://finances.worldbank.org/resource/gsdw-avpz/row-7rsr.82wk-dvyy'},text:
#
# ======subnodo 1.52======
# tag: member,attrib: {},text: Eritrea
# tag: amount_thousands_of_usd,attrib: {},text: 7129
# tag: percent_of_total_amount,attrib: {},text: 0.03
# tag: number_of_votes,attrib: {},text: 13728
# tag: percent_of_total_votes,attrib: {},text: 0.06
# tag: as_of_date,attrib: {},text: 2021-08-06T00:00:00
# tag: row,attrib: {'_id': 'row-wbxk_k9g8_nvnn', '_uuid': '00000000-0000-0000-2CE7-1C9C19802E2D', '_position': '0', '_address': 'https://finances.worldbank.org/resource/gsdw-avpz/row-wbxk_k9g8_nvnn'},text:
#
# ======subnodo 1.53======
# tag: member,attrib: {},text: Estonia
# tag: amount_thousands_of_usd,attrib: {},text: 10934
# tag: percent_of_total_amount,attrib: {},text: 0.05
# tag: number_of_votes,attrib: {},text: 17533
# tag: percent_of_total_votes,attrib: {},text: 0.08
# tag: as_of_date,attrib: {},text: 2021-08-06T00:00:00
# tag: row,attrib: {'_id': 'row-7uis_mfuf~dznq', '_uuid': '00000000-0000-0000-F627-4E10E2962C1C', '_position': '0', '_address': 'https://finances.worldbank.org/resource/gsdw-avpz/row-7uis_mfuf~dznq'},text:
#
# ======subnodo 1.54======
# tag: member,attrib: {},text: ESWATINI
# tag: amount_thousands_of_usd,attrib: {},text: 5215
# tag: percent_of_total_amount,attrib: {},text: 0.03
# tag: number_of_votes,attrib: {},text: 11814
# tag: percent_of_total_votes,attrib: {},text: 0.05
# tag: as_of_date,attrib: {},text: 2021-08-06T00:00:00
# tag: row,attrib: {'_id': 'row-qasr.4kha.btve', '_uuid': '00000000-0000-0000-DB1A-00E7458ED3D6', '_position': '0', '_address': 'https://finances.worldbank.org/resource/gsdw-avpz/row-qasr.4kha.btve'},text:
#
# ======subnodo 1.55======
# tag: member,attrib: {},text: Ethiopia
# tag: amount_thousands_of_usd,attrib: {},text: 968
# tag: percent_of_total_amount,attrib: {},text: 0.00
# tag: number_of_votes,attrib: {},text: 7567
# tag: percent_of_total_votes,attrib: {},text: 0.03
# tag: as_of_date,attrib: {},text: 2021-08-06T00:00:00
# tag: row,attrib: {'_id': 'row-5nj3-rkvz~3vca', '_uuid': '00000000-0000-0000-BD8A-7AA052ED0803', '_position': '0', '_address': 'https://finances.worldbank.org/resource/gsdw-avpz/row-5nj3-rkvz~3vca'},text:
#
# ======subnodo 1.56======
# tag: member,attrib: {},text: Fiji
# tag: amount_thousands_of_usd,attrib: {},text: 2188
# tag: percent_of_total_amount,attrib: {},text: 0.01
# tag: number_of_votes,attrib: {},text: 8787
# tag: percent_of_total_votes,attrib: {},text: 0.04
# tag: as_of_date,attrib: {},text: 2021-08-06T00:00:00
# tag: row,attrib: {'_id': 'row-9c8e-pd9r_kx7k', '_uuid': '00000000-0000-0000-8906-3CDB336CD1B1', '_position': '0', '_address': 'https://finances.worldbank.org/resource/gsdw-avpz/row-9c8e-pd9r_kx7k'},text:
#
# ======subnodo 1.57======
# tag: member,attrib: {},text: Finland
# tag: amount_thousands_of_usd,attrib: {},text: 126471
# tag: percent_of_total_amount,attrib: {},text: 0.61
# tag: number_of_votes,attrib: {},text: 133070
# tag: percent_of_total_votes,attrib: {},text: 0.60
# tag: as_of_date,attrib: {},text: 2021-08-06T00:00:00
# tag: row,attrib: {'_id': 'row-ifr6_7w3i-d858', '_uuid': '00000000-0000-0000-686E-B0C18173A8BD', '_position': '0', '_address': 'https://finances.worldbank.org/resource/gsdw-avpz/row-ifr6_7w3i-d858'},text:
#
# ======subnodo 1.58======
# tag: member,attrib: {},text: France
# tag: amount_thousands_of_usd,attrib: {},text: 975038
# tag: percent_of_total_amount,attrib: {},text: 4.69
# tag: number_of_votes,attrib: {},text: 981637
# tag: percent_of_total_votes,attrib: {},text: 4.46
# tag: as_of_date,attrib: {},text: 2021-08-06T00:00:00
# tag: row,attrib: {'_id': 'row-yb57_7zin_gkmc', '_uuid': '00000000-0000-0000-6531-767AE445B951', '_position': '0', '_address': 'https://finances.worldbank.org/resource/gsdw-avpz/row-yb57_7zin_gkmc'},text:
#
# ======subnodo 1.59======
# tag: member,attrib: {},text: Gabon
# tag: amount_thousands_of_usd,attrib: {},text: 9668
# tag: percent_of_total_amount,attrib: {},text: 0.05
# tag: number_of_votes,attrib: {},text: 16267
# tag: percent_of_total_votes,attrib: {},text: 0.07
# tag: as_of_date,attrib: {},text: 2021-08-06T00:00:00
# tag: row,attrib: {'_id': 'row-wpgj-ept7_9khd', '_uuid': '00000000-0000-0000-74D4-FC2F49D8B778', '_position': '0', '_address': 'https://finances.worldbank.org/resource/gsdw-avpz/row-wpgj-ept7_9khd'},text:
#
# ======subnodo 1.60======
# tag: member,attrib: {},text: Gambia, The
# tag: amount_thousands_of_usd,attrib: {},text: 717
# tag: percent_of_total_amount,attrib: {},text: 0.00
# tag: number_of_votes,attrib: {},text: 7316
# tag: percent_of_total_votes,attrib: {},text: 0.03
# tag: as_of_date,attrib: {},text: 2021-08-06T00:00:00
# tag: row,attrib: {'_id': 'row-in2e-w9wu_yfqi', '_uuid': '00000000-0000-0000-BB11-107BC6B6CA82', '_position': '0', '_address': 'https://finances.worldbank.org/resource/gsdw-avpz/row-in2e-w9wu_yfqi'},text:
#
# ======subnodo 1.61======
# tag: member,attrib: {},text: Georgia
# tag: amount_thousands_of_usd,attrib: {},text: 10522
# tag: percent_of_total_amount,attrib: {},text: 0.05
# tag: number_of_votes,attrib: {},text: 17121
# tag: percent_of_total_votes,attrib: {},text: 0.08
# tag: as_of_date,attrib: {},text: 2021-08-06T00:00:00
# tag: row,attrib: {'_id': 'row-2k6e_m99i_ej3e', '_uuid': '00000000-0000-0000-42BA-341B787A2381', '_position': '0', '_address': 'https://finances.worldbank.org/resource/gsdw-avpz/row-2k6e_m99i_ej3e'},text:
#
# ======subnodo 1.62======
# tag: member,attrib: {},text: Germany
# tag: amount_thousands_of_usd,attrib: {},text: 1094398
# tag: percent_of_total_amount,attrib: {},text: 5.27
# tag: number_of_votes,attrib: {},text: 1100997
# tag: percent_of_total_votes,attrib: {},text: 5.01
# tag: as_of_date,attrib: {},text: 2021-08-06T00:00:00
# tag: row,attrib: {'_id': 'row-wcyk~hdgu-dqge', '_uuid': '00000000-0000-0000-4FF1-16F8B03D37FB', '_position': '0', '_address': 'https://finances.worldbank.org/resource/gsdw-avpz/row-wcyk~hdgu-dqge'},text:
#
# ======subnodo 1.63======
# tag: member,attrib: {},text: Ghana
# tag: amount_thousands_of_usd,attrib: {},text: 42286
# tag: percent_of_total_amount,attrib: {},text: 0.20
# tag: number_of_votes,attrib: {},text: 48885
# tag: percent_of_total_votes,attrib: {},text: 0.22
# tag: as_of_date,attrib: {},text: 2021-08-06T00:00:00
# tag: row,attrib: {'_id': 'row-7bi7_mrmm-vpae', '_uuid': '00000000-0000-0000-94C4-6D9C662435B9', '_position': '0', '_address': 'https://finances.worldbank.org/resource/gsdw-avpz/row-7bi7_mrmm-vpae'},text:
#
# ======subnodo 1.64======
# tag: member,attrib: {},text: Greece
# tag: amount_thousands_of_usd,attrib: {},text: 56234
# tag: percent_of_total_amount,attrib: {},text: 0.27
# tag: number_of_votes,attrib: {},text: 62833
# tag: percent_of_total_votes,attrib: {},text: 0.29
# tag: as_of_date,attrib: {},text: 2021-08-06T00:00:00
# tag: row,attrib: {'_id': 'row-uc78-dv9w_2vxg', '_uuid': '00000000-0000-0000-D7E0-AB8B6CB6ACA6', '_position': '0', '_address': 'https://finances.worldbank.org/resource/gsdw-avpz/row-uc78-dv9w_2vxg'},text:
#
# ======subnodo 1.65======
# tag: member,attrib: {},text: Grenada
# tag: amount_thousands_of_usd,attrib: {},text: 564
# tag: percent_of_total_amount,attrib: {},text: 0.00
# tag: number_of_votes,attrib: {},text: 7163
# tag: percent_of_total_votes,attrib: {},text: 0.03
# tag: as_of_date,attrib: {},text: 2021-08-06T00:00:00
# tag: row,attrib: {'_id': 'row-zkzq_huwe.sz79', '_uuid': '00000000-0000-0000-52AF-0C69AE32A4B0', '_position': '0', '_address': 'https://finances.worldbank.org/resource/gsdw-avpz/row-zkzq_huwe.sz79'},text:
#
# ======subnodo 1.66======
# tag: member,attrib: {},text: Guatemala
# tag: amount_thousands_of_usd,attrib: {},text: 8265
# tag: percent_of_total_amount,attrib: {},text: 0.04
# tag: number_of_votes,attrib: {},text: 14864
# tag: percent_of_total_votes,attrib: {},text: 0.07
# tag: as_of_date,attrib: {},text: 2021-08-06T00:00:00
# tag: row,attrib: {'_id': 'row-jwu8~yg32~r4ru', '_uuid': '00000000-0000-0000-A18E-8E3618FFC8F3', '_position': '0', '_address': 'https://finances.worldbank.org/resource/gsdw-avpz/row-jwu8~yg32~r4ru'},text:
#
# ======subnodo 1.67======
# tag: member,attrib: {},text: Guinea
# tag: amount_thousands_of_usd,attrib: {},text: 2585
# tag: percent_of_total_amount,attrib: {},text: 0.01
# tag: number_of_votes,attrib: {},text: 9184
# tag: percent_of_total_votes,attrib: {},text: 0.04
# tag: as_of_date,attrib: {},text: 2021-08-06T00:00:00
# tag: row,attrib: {'_id': 'row-pv6z~4frf-fc2i', '_uuid': '00000000-0000-0000-DE30-22BBF065B2E6', '_position': '0', '_address': 'https://finances.worldbank.org/resource/gsdw-avpz/row-pv6z~4frf-fc2i'},text:
#
# ======subnodo 1.68======
# tag: member,attrib: {},text: Guinea-Bissau
# tag: amount_thousands_of_usd,attrib: {},text: 137
# tag: percent_of_total_amount,attrib: {},text: 0.00
# tag: number_of_votes,attrib: {},text: 6736
# tag: percent_of_total_votes,attrib: {},text: 0.03
# tag: as_of_date,attrib: {},text: 2021-08-06T00:00:00
# tag: row,attrib: {'_id': 'row-bzdd.4964~tz94', '_uuid': '00000000-0000-0000-CE0B-B7D62701762F', '_position': '0', '_address': 'https://finances.worldbank.org/resource/gsdw-avpz/row-bzdd.4964~tz94'},text:
#
# ======subnodo 1.69======
# tag: member,attrib: {},text: Guyana
# tag: amount_thousands_of_usd,attrib: {},text: 10613
# tag: percent_of_total_amount,attrib: {},text: 0.05
# tag: number_of_votes,attrib: {},text: 17212
# tag: percent_of_total_votes,attrib: {},text: 0.08
# tag: as_of_date,attrib: {},text: 2021-08-06T00:00:00
# tag: row,attrib: {'_id': 'row-m7ts-ptrg~nika', '_uuid': '00000000-0000-0000-F3F7-E1C8DE38F668', '_position': '0', '_address': 'https://finances.worldbank.org/resource/gsdw-avpz/row-m7ts-ptrg~nika'},text:
#
# ======subnodo 1.70======
# tag: member,attrib: {},text: Haiti
# tag: amount_thousands_of_usd,attrib: {},text: 6267
# tag: percent_of_total_amount,attrib: {},text: 0.03
# tag: number_of_votes,attrib: {},text: 12866
# tag: percent_of_total_votes,attrib: {},text: 0.06
# tag: as_of_date,attrib: {},text: 2021-08-06T00:00:00
# tag: row,attrib: {'_id': 'row-bv79.w87t.5bv4', '_uuid': '00000000-0000-0000-C414-8596727FC54A', '_position': '0', '_address': 'https://finances.worldbank.org/resource/gsdw-avpz/row-bv79.w87t.5bv4'},text:
#
# ======subnodo 1.71======
# tag: member,attrib: {},text: Honduras
# tag: amount_thousands_of_usd,attrib: {},text: 3774
# tag: percent_of_total_amount,attrib: {},text: 0.02
# tag: number_of_votes,attrib: {},text: 10373
# tag: percent_of_total_votes,attrib: {},text: 0.05
# tag: as_of_date,attrib: {},text: 2021-08-06T00:00:00
# tag: row,attrib: {'_id': 'row-77f9~fhxr_pg4b', '_uuid': '00000000-0000-0000-EDB4-D1FF3FCF279D', '_position': '0', '_address': 'https://finances.worldbank.org/resource/gsdw-avpz/row-77f9~fhxr_pg4b'},text:
#
# ======subnodo 1.72======
# tag: member,attrib: {},text: Hungary
# tag: amount_thousands_of_usd,attrib: {},text: 98996
# tag: percent_of_total_amount,attrib: {},text: 0.48
# tag: number_of_votes,attrib: {},text: 105595
# tag: percent_of_total_votes,attrib: {},text: 0.48
# tag: as_of_date,attrib: {},text: 2021-08-06T00:00:00
# tag: row,attrib: {'_id': 'row-6q5f-7udw_xe37', '_uuid': '00000000-0000-0000-8A75-3CBF6ACBCFF6', '_position': '0', '_address': 'https://finances.worldbank.org/resource/gsdw-avpz/row-6q5f-7udw_xe37'},text:
#
# ======subnodo 1.73======
# tag: member,attrib: {},text: Iceland
# tag: amount_thousands_of_usd,attrib: {},text: 1469
# tag: percent_of_total_amount,attrib: {},text: 0.01
# tag: number_of_votes,attrib: {},text: 8068
# tag: percent_of_total_votes,attrib: {},text: 0.04
# tag: as_of_date,attrib: {},text: 2021-08-06T00:00:00
# tag: row,attrib: {'_id': 'row-9w42.jjn2~77m8', '_uuid': '00000000-0000-0000-2F23-A2099DE69587', '_position': '0', '_address': 'https://finances.worldbank.org/resource/gsdw-avpz/row-9w42.jjn2~77m8'},text:
#
# ======subnodo 1.74======
# tag: member,attrib: {},text: India
# tag: amount_thousands_of_usd,attrib: {},text: 829462
# tag: percent_of_total_amount,attrib: {},text: 3.99
# tag: number_of_votes,attrib: {},text: 836061
# tag: percent_of_total_votes,attrib: {},text: 3.80
# tag: as_of_date,attrib: {},text: 2021-08-06T00:00:00
# tag: row,attrib: {'_id': 'row-d5us_36jg_hp62', '_uuid': '00000000-0000-0000-F863-57F93B89C3F3', '_position': '0', '_address': 'https://finances.worldbank.org/resource/gsdw-avpz/row-d5us_36jg_hp62'},text:
#
# ======subnodo 1.75======
# tag: member,attrib: {},text: Indonesia
# tag: amount_thousands_of_usd,attrib: {},text: 240952
# tag: percent_of_total_amount,attrib: {},text: 1.16
# tag: number_of_votes,attrib: {},text: 247551
# tag: percent_of_total_votes,attrib: {},text: 1.13
# tag: as_of_date,attrib: {},text: 2021-08-06T00:00:00
# tag: row,attrib: {'_id': 'row-9cty_kaem.kqnm', '_uuid': '00000000-0000-0000-D8D2-387FD2717205', '_position': '0', '_address': 'https://finances.worldbank.org/resource/gsdw-avpz/row-9cty_kaem.kqnm'},text:
#
# ======subnodo 1.76======
# tag: member,attrib: {},text: Iran, Islamic Republic of
# tag: amount_thousands_of_usd,attrib: {},text: 11010
# tag: percent_of_total_amount,attrib: {},text: 0.05
# tag: number_of_votes,attrib: {},text: 17609
# tag: percent_of_total_votes,attrib: {},text: 0.08
# tag: as_of_date,attrib: {},text: 2021-08-06T00:00:00
# tag: row,attrib: {'_id': 'row-rx7s_prsn~2m26', '_uuid': '00000000-0000-0000-F481-8A6998365545', '_position': '0', '_address': 'https://finances.worldbank.org/resource/gsdw-avpz/row-rx7s_prsn~2m26'},text:
#
# ======subnodo 1.77======
# tag: member,attrib: {},text: Iraq
# tag: amount_thousands_of_usd,attrib: {},text: 1121
# tag: percent_of_total_amount,attrib: {},text: 0.01
# tag: number_of_votes,attrib: {},text: 7720
# tag: percent_of_total_votes,attrib: {},text: 0.04
# tag: as_of_date,attrib: {},text: 2021-08-06T00:00:00
# tag: row,attrib: {'_id': 'row-afpp~ckke.fza4', '_uuid': '00000000-0000-0000-AA14-B2887EA4D468', '_position': '0', '_address': 'https://finances.worldbank.org/resource/gsdw-avpz/row-afpp~ckke.fza4'},text:
#
# ======subnodo 1.78======
# tag: member,attrib: {},text: Ireland
# tag: amount_thousands_of_usd,attrib: {},text: 14055
# tag: percent_of_total_amount,attrib: {},text: 0.07
# tag: number_of_votes,attrib: {},text: 20654
# tag: percent_of_total_votes,attrib: {},text: 0.09
# tag: as_of_date,attrib: {},text: 2021-08-06T00:00:00
# tag: row,attrib: {'_id': 'row-q76n.t4br_xg47', '_uuid': '00000000-0000-0000-BD97-AF07C1F53B54', '_position': '0', '_address': 'https://finances.worldbank.org/resource/gsdw-avpz/row-q76n.t4br_xg47'},text:
#
# ======subnodo 1.79======
# tag: member,attrib: {},text: Israel
# tag: amount_thousands_of_usd,attrib: {},text: 19518
# tag: percent_of_total_amount,attrib: {},text: 0.09
# tag: number_of_votes,attrib: {},text: 26117
# tag: percent_of_total_votes,attrib: {},text: 0.12
# tag: as_of_date,attrib: {},text: 2021-08-06T00:00:00
# tag: row,attrib: {'_id': 'row-ef29.8y25_xk6n', '_uuid': '00000000-0000-0000-4E2C-3118E15B3A6E', '_position': '0', '_address': 'https://finances.worldbank.org/resource/gsdw-avpz/row-ef29.8y25_xk6n'},text:
#
# ======subnodo 1.80======
# tag: member,attrib: {},text: Italy
# tag: amount_thousands_of_usd,attrib: {},text: 655387
# tag: percent_of_total_amount,attrib: {},text: 3.15
# tag: number_of_votes,attrib: {},text: 661986
# tag: percent_of_total_votes,attrib: {},text: 3.01
# tag: as_of_date,attrib: {},text: 2021-08-06T00:00:00
# tag: row,attrib: {'_id': 'row-6c6z-9s7t~k6ri', '_uuid': '00000000-0000-0000-2535-98E3ED36D151', '_position': '0', '_address': 'https://finances.worldbank.org/resource/gsdw-avpz/row-6c6z-9s7t~k6ri'},text:
#
# ======subnodo 1.81======
# tag: member,attrib: {},text: Jamaica
# tag: amount_thousands_of_usd,attrib: {},text: 32648
# tag: percent_of_total_amount,attrib: {},text: 0.16
# tag: number_of_votes,attrib: {},text: 39247
# tag: percent_of_total_votes,attrib: {},text: 0.18
# tag: as_of_date,attrib: {},text: 2021-08-06T00:00:00
# tag: row,attrib: {'_id': 'row-kvjn~mnai_gxhb', '_uuid': '00000000-0000-0000-EB3D-F2BB452444A5', '_position': '0', '_address': 'https://finances.worldbank.org/resource/gsdw-avpz/row-kvjn~mnai_gxhb'},text:
#
# ======subnodo 1.82======
# tag: member,attrib: {},text: Japan
# tag: amount_thousands_of_usd,attrib: {},text: 1716263
# tag: percent_of_total_amount,attrib: {},text: 8.26
# tag: number_of_votes,attrib: {},text: 1722862
# tag: percent_of_total_votes,attrib: {},text: 7.83
# tag: as_of_date,attrib: {},text: 2021-08-06T00:00:00
# tag: row,attrib: {'_id': 'row-s58c_6cm6~axsf', '_uuid': '00000000-0000-0000-DF25-F280029DE4B0', '_position': '0', '_address': 'https://finances.worldbank.org/resource/gsdw-avpz/row-s58c_6cm6~axsf'},text:
#
# ======subnodo 1.83======
# tag: member,attrib: {},text: Jordan
# tag: amount_thousands_of_usd,attrib: {},text: 7175
# tag: percent_of_total_amount,attrib: {},text: 0.03
# tag: number_of_votes,attrib: {},text: 13774
# tag: percent_of_total_votes,attrib: {},text: 0.06
# tag: as_of_date,attrib: {},text: 2021-08-06T00:00:00
# tag: row,attrib: {'_id': 'row-iapf~27j8_crii', '_uuid': '00000000-0000-0000-22B5-983808B79B98', '_position': '0', '_address': 'https://finances.worldbank.org/resource/gsdw-avpz/row-iapf~27j8_crii'},text:
#
# ======subnodo 1.84======
# tag: member,attrib: {},text: Kazakhstan
# tag: amount_thousands_of_usd,attrib: {},text: 35355
# tag: percent_of_total_amount,attrib: {},text: 0.17
# tag: number_of_votes,attrib: {},text: 41954
# tag: percent_of_total_votes,attrib: {},text: 0.19
# tag: as_of_date,attrib: {},text: 2021-08-06T00:00:00
# tag: row,attrib: {'_id': 'row-4jjy.sym5~dp78', '_uuid': '00000000-0000-0000-28E2-B2215DB1E9AB', '_position': '0', '_address': 'https://finances.worldbank.org/resource/gsdw-avpz/row-4jjy.sym5~dp78'},text:
#
# ======subnodo 1.85======
# tag: member,attrib: {},text: Kenya
# tag: amount_thousands_of_usd,attrib: {},text: 30811
# tag: percent_of_total_amount,attrib: {},text: 0.15
# tag: number_of_votes,attrib: {},text: 37410
# tag: percent_of_total_votes,attrib: {},text: 0.17
# tag: as_of_date,attrib: {},text: 2021-08-06T00:00:00
# tag: row,attrib: {'_id': 'row-cgk2_w97r-7zzp', '_uuid': '00000000-0000-0000-5735-024230765297', '_position': '0', '_address': 'https://finances.worldbank.org/resource/gsdw-avpz/row-cgk2_w97r-7zzp'},text:
#
# ======subnodo 1.86======
# tag: member,attrib: {},text: Kiribati
# tag: amount_thousands_of_usd,attrib: {},text: 91
# tag: percent_of_total_amount,attrib: {},text: 0.00
# tag: number_of_votes,attrib: {},text: 6690
# tag: percent_of_total_votes,attrib: {},text: 0.03
# tag: as_of_date,attrib: {},text: 2021-08-06T00:00:00
# tag: row,attrib: {'_id': 'row-d89m~b2gd_t5ku', '_uuid': '00000000-0000-0000-2594-35F1D2791896', '_position': '0', '_address': 'https://finances.worldbank.org/resource/gsdw-avpz/row-d89m~b2gd_t5ku'},text:
#
# ======subnodo 1.87======
# tag: member,attrib: {},text: Korea, Republic of
# tag: amount_thousands_of_usd,attrib: {},text: 241241
# tag: percent_of_total_amount,attrib: {},text: 1.16
# tag: number_of_votes,attrib: {},text: 247840
# tag: percent_of_total_votes,attrib: {},text: 1.13
# tag: as_of_date,attrib: {},text: 2021-08-06T00:00:00
# tag: row,attrib: {'_id': 'row-8e43.8kiw_zi2n', '_uuid': '00000000-0000-0000-3397-1D4F25DD79CF', '_position': '0', '_address': 'https://finances.worldbank.org/resource/gsdw-avpz/row-8e43.8kiw_zi2n'},text:
#
# ======subnodo 1.88======
# tag: member,attrib: {},text: Kosovo
# tag: amount_thousands_of_usd,attrib: {},text: 11086
# tag: percent_of_total_amount,attrib: {},text: 0.05
# tag: number_of_votes,attrib: {},text: 17685
# tag: percent_of_total_votes,attrib: {},text: 0.08
# tag: as_of_date,attrib: {},text: 2021-08-06T00:00:00
# tag: row,attrib: {'_id': 'row-prer.q8ax.sgnf', '_uuid': '00000000-0000-0000-016E-94D7811B2798', '_position': '0', '_address': 'https://finances.worldbank.org/resource/gsdw-avpz/row-prer.q8ax.sgnf'},text:
#
# ======subnodo 1.89======
# tag: member,attrib: {},text: Kuwait
# tag: amount_thousands_of_usd,attrib: {},text: 114925
# tag: percent_of_total_amount,attrib: {},text: 0.55
# tag: number_of_votes,attrib: {},text: 121524
# tag: percent_of_total_votes,attrib: {},text: 0.55
# tag: as_of_date,attrib: {},text: 2021-08-06T00:00:00
# tag: row,attrib: {'_id': 'row-dmxe.8twt.3zuu', '_uuid': '00000000-0000-0000-4FB7-D018D2DC70F0', '_position': '0', '_address': 'https://finances.worldbank.org/resource/gsdw-avpz/row-dmxe.8twt.3zuu'},text:
#
# ======subnodo 1.90======
# tag: member,attrib: {},text: Kyrgyz Republic
# tag: amount_thousands_of_usd,attrib: {},text: 13114
# tag: percent_of_total_amount,attrib: {},text: 0.06
# tag: number_of_votes,attrib: {},text: 19713
# tag: percent_of_total_votes,attrib: {},text: 0.09
# tag: as_of_date,attrib: {},text: 2021-08-06T00:00:00
# tag: row,attrib: {'_id': 'row-74vb~mguu-ps96', '_uuid': '00000000-0000-0000-8AAE-1A8D4F902F2F', '_position': '0', '_address': 'https://finances.worldbank.org/resource/gsdw-avpz/row-74vb~mguu-ps96'},text:
#
# ======subnodo 1.91======
# tag: member,attrib: {},text: Lao People's Democratic Republic
# tag: amount_thousands_of_usd,attrib: {},text: 2120
# tag: percent_of_total_amount,attrib: {},text: 0.01
# tag: number_of_votes,attrib: {},text: 8719
# tag: percent_of_total_votes,attrib: {},text: 0.04
# tag: as_of_date,attrib: {},text: 2021-08-06T00:00:00
# tag: row,attrib: {'_id': 'row-pjrf.hgpg~h7ut', '_uuid': '00000000-0000-0000-AEE4-4E10230B9E6E', '_position': '0', '_address': 'https://finances.worldbank.org/resource/gsdw-avpz/row-pjrf.hgpg~h7ut'},text:
#
# ======subnodo 1.92======
# tag: member,attrib: {},text: Latvia
# tag: amount_thousands_of_usd,attrib: {},text: 18253
# tag: percent_of_total_amount,attrib: {},text: 0.09
# tag: number_of_votes,attrib: {},text: 24852
# tag: percent_of_total_votes,attrib: {},text: 0.11
# tag: as_of_date,attrib: {},text: 2021-08-06T00:00:00
# ...
#
# ======subnodo 1.155======
# tag: member,attrib: {},text: St. Kitts and Nevis
# tag: amount_thousands_of_usd,attrib: {},text: 4864
# tag: percent_of_total_amount,attrib: {},text: 0.02
# tag: number_of_votes,attrib: {},text: 11463
# tag: percent_of_total_votes,attrib: {},text: 0.05
# tag: as_of_date,attrib: {},text: 2021-08-06T00:00:00
# tag: row,attrib: {'_id': 'row-tifp.3867-r344', '_uuid': '00000000-0000-0000-681D-9DD0D878CFC8', '_position': '0', '_address': 'https://finances.worldbank.org/resource/gsdw-avpz/row-tifp.3867-r344'},text:
#
# ======subnodo 1.156======
# tag: member,attrib: {},text: St. Lucia
# tag: amount_thousands_of_usd,attrib: {},text: 564
# tag: percent_of_total_amount,attrib: {},text: 0.00
# tag: number_of_votes,attrib: {},text: 7163
# tag: percent_of_total_votes,attrib: {},text: 0.03
# tag: as_of_date,attrib: {},text: 2021-08-06T00:00:00
# tag: row,attrib: {'_id': 'row-iqrw-zczz_gi9b', '_uuid': '00000000-0000-0000-E9A7-3B6099B4FE2B', '_position': '0', '_address': 'https://finances.worldbank.org/resource/gsdw-avpz/row-iqrw-zczz_gi9b'},text:
#
# ======subnodo 1.157======
# tag: member,attrib: {},text: Sudan
# tag: amount_thousands_of_usd,attrib: {},text: 846
# tag: percent_of_total_amount,attrib: {},text: 0.00
# tag: number_of_votes,attrib: {},text: 7445
# tag: percent_of_total_votes,attrib: {},text: 0.03
# tag: as_of_date,attrib: {},text: 2021-08-06T00:00:00
# tag: row,attrib: {'_id': 'row-9c75.6u54_d62n', '_uuid': '00000000-0000-0000-8A21-29233B110C53', '_position': '0', '_address': 'https://finances.worldbank.org/resource/gsdw-avpz/row-9c75.6u54_d62n'},text:
#
# ======subnodo 1.158======
# tag: member,attrib: {},text: Suriname
# tag: amount_thousands_of_usd,attrib: {},text: 4727
# tag: percent_of_total_amount,attrib: {},text: 0.02
# tag: number_of_votes,attrib: {},text: 11326
# tag: percent_of_total_votes,attrib: {},text: 0.05
# tag: as_of_date,attrib: {},text: 2021-08-06T00:00:00
# tag: row,attrib: {'_id': 'row-gnpd_xy3h.j8tw', '_uuid': '00000000-0000-0000-42AC-07EDCD5EABF3', '_position': '0', '_address': 'https://finances.worldbank.org/resource/gsdw-avpz/row-gnpd_xy3h.j8tw'},text:
#
# ======subnodo 1.159======
# tag: member,attrib: {},text: Sweden
# tag: amount_thousands_of_usd,attrib: {},text: 234918
# tag: percent_of_total_amount,attrib: {},text: 1.13
# tag: number_of_votes,attrib: {},text: 241517
# tag: percent_of_total_votes,attrib: {},text: 1.10
# tag: as_of_date,attrib: {},text: 2021-08-06T00:00:00
# tag: row,attrib: {'_id': 'row-7q4a-npkd~653q', '_uuid': '00000000-0000-0000-BA82-96F3524B57E5', '_position': '0', '_address': 'https://finances.worldbank.org/resource/gsdw-avpz/row-7q4a-npkd~653q'},text:
#
# ======subnodo 1.160======
# tag: member,attrib: {},text: Switzerland
# tag: amount_thousands_of_usd,attrib: {},text: 352859
# tag: percent_of_total_amount,attrib: {},text: 1.70
# tag: number_of_votes,attrib: {},text: 359458
# tag: percent_of_total_votes,attrib: {},text: 1.63
# tag: as_of_date,attrib: {},text: 2021-08-06T00:00:00
# tag: row,attrib: {'_id': 'row-ps88~4k32~i7hg', '_uuid': '00000000-0000-0000-7E59-7F88FB5C400A', '_position': '0', '_address': 'https://finances.worldbank.org/resource/gsdw-avpz/row-ps88~4k32~i7hg'},text:
#
# ======subnodo 1.161======
# tag: member,attrib: {},text: Syrian Arab Republic
# tag: amount_thousands_of_usd,attrib: {},text: 1479
# tag: percent_of_total_amount,attrib: {},text: 0.01
# tag: number_of_votes,attrib: {},text: 8078
# tag: percent_of_total_votes,attrib: {},text: 0.04
# tag: as_of_date,attrib: {},text: 2021-08-06T00:00:00
# tag: row,attrib: {'_id': 'row-nih2_nif6~r3fi', '_uuid': '00000000-0000-0000-EAF4-D2AD88EA50E8', '_position': '0', '_address': 'https://finances.worldbank.org/resource/gsdw-avpz/row-nih2_nif6~r3fi'},text:
#
# ======subnodo 1.162======
# tag: member,attrib: {},text: Tajikistan
# tag: amount_thousands_of_usd,attrib: {},text: 9241
# tag: percent_of_total_amount,attrib: {},text: 0.04
# tag: number_of_votes,attrib: {},text: 15840
# tag: percent_of_total_votes,attrib: {},text: 0.07
# tag: as_of_date,attrib: {},text: 2021-08-06T00:00:00
# tag: row,attrib: {'_id': 'row-xnvq-x3rv_ad25', '_uuid': '00000000-0000-0000-FCB4-7307033CE6B9', '_position': '0', '_address': 'https://finances.worldbank.org/resource/gsdw-avpz/row-xnvq-x3rv_ad25'},text:
#
# ======subnodo 1.163======
# tag: member,attrib: {},text: Tanzania
# tag: amount_thousands_of_usd,attrib: {},text: 7647
# tag: percent_of_total_amount,attrib: {},text: 0.04
# tag: number_of_votes,attrib: {},text: 14246
# tag: percent_of_total_votes,attrib: {},text: 0.06
# tag: as_of_date,attrib: {},text: 2021-08-06T00:00:00
# tag: row,attrib: {'_id': 'row-6kwr~sh97.sykc', '_uuid': '00000000-0000-0000-14D6-84E88B2DB646', '_position': '0', '_address': 'https://finances.worldbank.org/resource/gsdw-avpz/row-6kwr~sh97.sykc'},text:
#
# ======subnodo 1.164======
# tag: member,attrib: {},text: Thailand
# tag: amount_thousands_of_usd,attrib: {},text: 99495
# tag: percent_of_total_amount,attrib: {},text: 0.48
# tag: number_of_votes,attrib: {},text: 106094
# tag: percent_of_total_votes,attrib: {},text: 0.48
# tag: as_of_date,attrib: {},text: 2021-08-06T00:00:00
# tag: row,attrib: {'_id': 'row-87sx.ynuq~4c6t', '_uuid': '00000000-0000-0000-6CEE-F7F53B4AB745', '_position': '0', '_address': 'https://finances.worldbank.org/resource/gsdw-avpz/row-87sx.ynuq~4c6t'},text:
#
# ======subnodo 1.165======
# tag: member,attrib: {},text: Timor-Leste
# tag: amount_thousands_of_usd,attrib: {},text: 5924
# tag: percent_of_total_amount,attrib: {},text: 0.03
# tag: number_of_votes,attrib: {},text: 12523
# tag: percent_of_total_votes,attrib: {},text: 0.06
# tag: as_of_date,attrib: {},text: 2021-08-06T00:00:00
# tag: row,attrib: {'_id': 'row-gfku-ge5u~t5fg', '_uuid': '00000000-0000-0000-0198-3978310D8167', '_position': '0', '_address': 'https://finances.worldbank.org/resource/gsdw-avpz/row-gfku-ge5u~t5fg'},text:
#
# ======subnodo 1.166======
# tag: member,attrib: {},text: Togo
# tag: amount_thousands_of_usd,attrib: {},text: 6161
# tag: percent_of_total_amount,attrib: {},text: 0.03
# tag: number_of_votes,attrib: {},text: 12760
# tag: percent_of_total_votes,attrib: {},text: 0.06
# tag: as_of_date,attrib: {},text: 2021-08-06T00:00:00
# tag: row,attrib: {'_id': 'row-bica_2kn8_uvz2', '_uuid': '00000000-0000-0000-BAFC-0A90FE004D08', '_position': '0', '_address': 'https://finances.worldbank.org/resource/gsdw-avpz/row-bica_2kn8_uvz2'},text:
#
# ======subnodo 1.167======
# tag: member,attrib: {},text: Tonga
# tag: amount_thousands_of_usd,attrib: {},text: 581
# tag: percent_of_total_amount,attrib: {},text: 0.00
# tag: number_of_votes,attrib: {},text: 7180
# tag: percent_of_total_votes,attrib: {},text: 0.03
# tag: as_of_date,attrib: {},text: 2021-08-06T00:00:00
# tag: row,attrib: {'_id': 'row-sraj~zrbn_gcrm', '_uuid': '00000000-0000-0000-1A0A-2B83697A14AE', '_position': '0', '_address': 'https://finances.worldbank.org/resource/gsdw-avpz/row-sraj~zrbn_gcrm'},text:
#
# ======subnodo 1.168======
# tag: member,attrib: {},text: Trinidad and Tobago
# tag: amount_thousands_of_usd,attrib: {},text: 31352
# tag: percent_of_total_amount,attrib: {},text: 0.15
# tag: number_of_votes,attrib: {},text: 37951
# tag: percent_of_total_votes,attrib: {},text: 0.17
# tag: as_of_date,attrib: {},text: 2021-08-06T00:00:00
# tag: row,attrib: {'_id': 'row-uhbs_i4e4~6e6f', '_uuid': '00000000-0000-0000-7E00-91B2C00CC0F6', '_position': '0', '_address': 'https://finances.worldbank.org/resource/gsdw-avpz/row-uhbs_i4e4~6e6f'},text:
#
# ======subnodo 1.169======
# tag: member,attrib: {},text: Tunisia
# tag: amount_thousands_of_usd,attrib: {},text: 28773
# tag: percent_of_total_amount,attrib: {},text: 0.14
# tag: number_of_votes,attrib: {},text: 35372
# tag: percent_of_total_votes,attrib: {},text: 0.16
# tag: as_of_date,attrib: {},text: 2021-08-06T00:00:00
# tag: row,attrib: {'_id': 'row-epja-ewme~y92v', '_uuid': '00000000-0000-0000-54C4-DE040EADB26E', '_position': '0', '_address': 'https://finances.worldbank.org/resource/gsdw-avpz/row-epja-ewme~y92v'},text:
#
# ======subnodo 1.170======
# tag: member,attrib: {},text: Turkey
# tag: amount_thousands_of_usd,attrib: {},text: 120751
# tag: percent_of_total_amount,attrib: {},text: 0.58
# tag: number_of_votes,attrib: {},text: 127350
# tag: percent_of_total_votes,attrib: {},text: 0.58
# tag: as_of_date,attrib: {},text: 2021-08-06T00:00:00
# tag: row,attrib: {'_id': 'row-m65d~w7cg~p48n', '_uuid': '00000000-0000-0000-1D3A-BC3CA98D9919', '_position': '0', '_address': 'https://finances.worldbank.org/resource/gsdw-avpz/row-m65d~w7cg~p48n'},text:
#
# ======subnodo 1.171======
# tag: member,attrib: {},text: Turkmenistan
# tag: amount_thousands_of_usd,attrib: {},text: 6176
# tag: percent_of_total_amount,attrib: {},text: 0.03
# tag: number_of_votes,attrib: {},text: 12775
# tag: percent_of_total_votes,attrib: {},text: 0.06
# tag: as_of_date,attrib: {},text: 2021-08-06T00:00:00
# tag: row,attrib: {'_id': 'row-wz4i.8zmr-9vre', '_uuid': '00000000-0000-0000-72E6-27B927DA06E6', '_position': '0', '_address': 'https://finances.worldbank.org/resource/gsdw-avpz/row-wz4i.8zmr-9vre'},text:
#
# ======subnodo 1.172======
# tag: member,attrib: {},text: Tuvalu
# tag: amount_thousands_of_usd,attrib: {},text: 520
# tag: percent_of_total_amount,attrib: {},text: 0.00
# tag: number_of_votes,attrib: {},text: 7119
# tag: percent_of_total_votes,attrib: {},text: 0.03
# tag: as_of_date,attrib: {},text: 2021-08-06T00:00:00
# tag: row,attrib: {'_id': 'row-sji8-c54b~29tc', '_uuid': '00000000-0000-0000-2EEA-C2B1E5E23E90', '_position': '0', '_address': 'https://finances.worldbank.org/resource/gsdw-avpz/row-sji8-c54b~29tc'},text:
#
# ======subnodo 1.173======
# tag: member,attrib: {},text: Uganda
# tag: amount_thousands_of_usd,attrib: {},text: 5604
# tag: percent_of_total_amount,attrib: {},text: 0.03
# tag: number_of_votes,attrib: {},text: 12203
# tag: percent_of_total_votes,attrib: {},text: 0.06
# tag: as_of_date,attrib: {},text: 2021-08-06T00:00:00
# tag: row,attrib: {'_id': 'row-zi2g_cgdv_264v', '_uuid': '00000000-0000-0000-971D-3923BE377889', '_position': '0', '_address': 'https://finances.worldbank.org/resource/gsdw-avpz/row-zi2g_cgdv_264v'},text:
#
# ======subnodo 1.174======
# tag: member,attrib: {},text: Ukraine
# tag: amount_thousands_of_usd,attrib: {},text: 77458
# tag: percent_of_total_amount,attrib: {},text: 0.37
# tag: number_of_votes,attrib: {},text: 84057
# tag: percent_of_total_votes,attrib: {},text: 0.38
# tag: as_of_date,attrib: {},text: 2021-08-06T00:00:00
# tag: row,attrib: {'_id': 'row-rwpc.daph-k7h2', '_uuid': '00000000-0000-0000-2F68-EE24977C646B', '_position': '0', '_address': 'https://finances.worldbank.org/resource/gsdw-avpz/row-rwpc.daph-k7h2'},text:
#
# ======subnodo 1.175======
# tag: member,attrib: {},text: United Arab Emirates
# tag: amount_thousands_of_usd,attrib: {},text: 30750
# tag: percent_of_total_amount,attrib: {},text: 0.15
# tag: number_of_votes,attrib: {},text: 37349
# tag: percent_of_total_votes,attrib: {},text: 0.17
# tag: as_of_date,attrib: {},text: 2021-08-06T00:00:00
# tag: row,attrib: {'_id': 'row-bq5r-k6u3-7nrc', '_uuid': '00000000-0000-0000-C637-DF4962AF586D', '_position': '0', '_address': 'https://finances.worldbank.org/resource/gsdw-avpz/row-bq5r-k6u3-7nrc'},text:
#
# ======subnodo 1.176======
# tag: member,attrib: {},text: United Kingdom
# tag: amount_thousands_of_usd,attrib: {},text: 975038
# tag: percent_of_total_amount,attrib: {},text: 4.69
# tag: number_of_votes,attrib: {},text: 981637
# tag: percent_of_total_votes,attrib: {},text: 4.46
# tag: as_of_date,attrib: {},text: 2021-08-06T00:00:00
# tag: row,attrib: {'_id': 'row-usmv~h879.r4mi', '_uuid': '00000000-0000-0000-B390-4922525704BE', '_position': '0', '_address': 'https://finances.worldbank.org/resource/gsdw-avpz/row-usmv~h879.r4mi'},text:
#
# ======subnodo 1.177======
# tag: member,attrib: {},text: United States
# tag: amount_thousands_of_usd,attrib: {},text: 4341278
# tag: percent_of_total_amount,attrib: {},text: 20.90
# tag: number_of_votes,attrib: {},text: 4347877
# tag: percent_of_total_votes,attrib: {},text: 19.77
# tag: as_of_date,attrib: {},text: 2021-08-06T00:00:00
# tag: row,attrib: {'_id': 'row-f8sr_kgsw_xwen', '_uuid': '00000000-0000-0000-A27E-C8554F4BA725', '_position': '0', '_address': 'https://finances.worldbank.org/resource/gsdw-avpz/row-f8sr_kgsw_xwen'},text:
#
# ======subnodo 1.178======
# tag: member,attrib: {},text: Uruguay
# tag: amount_thousands_of_usd,attrib: {},text: 27212
# tag: percent_of_total_amount,attrib: {},text: 0.13
# tag: number_of_votes,attrib: {},text: 33811
# tag: percent_of_total_votes,attrib: {},text: 0.15
# tag: as_of_date,attrib: {},text: 2021-08-06T00:00:00
# tag: row,attrib: {'_id': 'row-ew97_3b5f~jr6r', '_uuid': '00000000-0000-0000-DC51-460093927FAB', '_position': '0', '_address': 'https://finances.worldbank.org/resource/gsdw-avpz/row-ew97_3b5f~jr6r'},text:
#
# ======subnodo 1.179======
# tag: member,attrib: {},text: Uzbekistan
# tag: amount_thousands_of_usd,attrib: {},text: 29530
# tag: percent_of_total_amount,attrib: {},text: 0.14
# tag: number_of_votes,attrib: {},text: 36129
# tag: percent_of_total_votes,attrib: {},text: 0.16
# tag: as_of_date,attrib: {},text: 2021-08-06T00:00:00
# tag: row,attrib: {'_id': 'row-mv6i~ngz9_icb5', '_uuid': '00000000-0000-0000-52D5-657EFB314108', '_position': '0', '_address': 'https://finances.worldbank.org/resource/gsdw-avpz/row-mv6i~ngz9_icb5'},text:
#
# ======subnodo 1.180======
# tag: member,attrib: {},text: Vanuatu
# tag: amount_thousands_of_usd,attrib: {},text: 419
# tag: percent_of_total_amount,attrib: {},text: 0.00
# tag: number_of_votes,attrib: {},text: 7018
# tag: percent_of_total_votes,attrib: {},text: 0.03
# tag: as_of_date,attrib: {},text: 2021-08-06T00:00:00
# tag: row,attrib: {'_id': 'row-qrgm-r2gc-vmf5', '_uuid': '00000000-0000-0000-6B23-1E7100931F81', '_position': '0', '_address': 'https://finances.worldbank.org/resource/gsdw-avpz/row-qrgm-r2gc-vmf5'},text:
#
# ======subnodo 1.181======
# tag: member,attrib: {},text: Venezuela, Republica Bolivariana de
# tag: amount_thousands_of_usd,attrib: {},text: 210347
# tag: percent_of_total_amount,attrib: {},text: 1.01
# tag: number_of_votes,attrib: {},text: 216946
# tag: percent_of_total_votes,attrib: {},text: 0.99
# tag: as_of_date,attrib: {},text: 2021-08-06T00:00:00
# tag: row,attrib: {'_id': 'row-v949_etve.z4iu', '_uuid': '00000000-0000-0000-D24E-335270F95588', '_position': '0', '_address': 'https://finances.worldbank.org/resource/gsdw-avpz/row-v949_etve.z4iu'},text:
#
# ======subnodo 1.182======
# tag: member,attrib: {},text: Vietnam
# tag: amount_thousands_of_usd,attrib: {},text: 3401
# tag: percent_of_total_amount,attrib: {},text: 0.02
# tag: number_of_votes,attrib: {},text: 10000
# tag: percent_of_total_votes,attrib: {},text: 0.05
# tag: as_of_date,attrib: {},text: 2021-08-06T00:00:00
# tag: row,attrib: {'_id': 'row-44vq_uwjv-izcc', '_uuid': '00000000-0000-0000-2518-4C1118CD0F83', '_position': '0', '_address': 'https://finances.worldbank.org/resource/gsdw-avpz/row-44vq_uwjv-izcc'},text:
#
# ======subnodo 1.183======
# tag: member,attrib: {},text: Yemen, Republic of
# tag: amount_thousands_of_usd,attrib: {},text: 5452
# tag: percent_of_total_amount,attrib: {},text: 0.03
# tag: number_of_votes,attrib: {},text: 12051
# tag: percent_of_total_votes,attrib: {},text: 0.05
# tag: as_of_date,attrib: {},text: 2021-08-06T00:00:00
# tag: row,attrib: {'_id': 'row-pc34.25ft~32ca', '_uuid': '00000000-0000-0000-A697-BD6CF2EAF622', '_position': '0', '_address': 'https://finances.worldbank.org/resource/gsdw-avpz/row-pc34.25ft~32ca'},text:
#
# ======subnodo 1.184======
# tag: member,attrib: {},text: Zambia
# tag: amount_thousands_of_usd,attrib: {},text: 9805
# tag: percent_of_total_amount,attrib: {},text: 0.05
# tag: number_of_votes,attrib: {},text: 16404
# tag: percent_of_total_votes,attrib: {},text: 0.07
# tag: as_of_date,attrib: {},text: 2021-08-06T00:00:00
# tag: row,attrib: {'_id': 'row-7dy3~4bef.3bfi', '_uuid': '00000000-0000-0000-CD0C-FD2EA362B90B', '_position': '0', '_address': 'https://finances.worldbank.org/resource/gsdw-avpz/row-7dy3~4bef.3bfi'},text:
#
# ======subnodo 1.185======
# tag: member,attrib: {},text: Zimbabwe
# tag: amount_thousands_of_usd,attrib: {},text: 24513
# tag: percent_of_total_amount,attrib: {},text: 0.12
# tag: number_of_votes,attrib: {},text: 31112
# tag: percent_of_total_votes,attrib: {},text: 0.14
# tag: as_of_date,attrib: {},text: 2021-08-06T00:00:00

# %% [markdown]
# ---

# %% [markdown]
# # Archivos SHP

# %%
# %conda !pip !conda
# %pip install geopandas

# %%
import geopandas as gpd

# %%
rutaCOVID='/content/drive/MyDrive/Colab Notebooks/Módulo 1 - Extracción de datos de diferentes fuentes/COVID_INDIA_POC-shp/'
gpd.read_file(rutaCOVID+'COVID_INDIA_POC.shp')
# Out:
#      OBJECTID  RecordID2                                            Address  \
# 0           1        163  No. 09, Samiyam Road, Thafasenthirpuram, Aniks...
# 1           2        977  noor imaging center almedia bldg junction of s...
# 2           3       1143  D/o Elumalai, Kila Street, Ariyalur, (Local Ad...
# 3           4        965  C-403, Padmraj Residency, Opp. Kedar Society, ...
# 4           5        318  B-993 FIRST FLOOR BACK SIDE NEAR NHPC CHOWK GR...
# ..        ...        ...                                                ...
# 507       508       1192                              GAJULARAMARAM MEDCHAL
# 508       509       1200                              SULTANPURA ,HYDERABAD
# 509       510       1202                              SULTHANPURA,HYDERABAD
# 510       511       1236                              KISHAN BAGH HYDERABAD
# 511       512       1390                              Kasba, Ward no1, Egra
#
#         State_UT            District     GC_LAT     GC_LON  \
# 0     Tamil Nadu             CHENNAI  11.312304  79.709747
# 1    MAHARASHTRA              MUMBAI  19.144093  72.842525
# 2     Tamil Nadu            Ariyalur  11.140059  79.078628
# 3    Maharashtra               THANE  19.157694  73.077513
# 4        HARYANA           FARIDABAD  28.471226  77.288265
# ..           ...                 ...        ...        ...
# 507    Telangana  MEDCHAL MALKAJGIRI  17.561118  78.492872
# 508    Telangana           HYDERABAD  17.375189  78.487542
# 509    Telangana           HYDERABAD  17.555122  78.308114
# 510    TELANGANA           HYDERABAD  17.355327  78.443261
# 511  West Bengal      MEDINIPUR EAST  21.912969  87.532167
#
#                       geometry
# 0    POINT (79.70975 11.31230)
# 1    POINT (72.84253 19.14409)
# 2    POINT (79.07863 11.14006)
# 3    POINT (73.07751 19.15769)
# 4    POINT (77.28827 28.47123)
# ..                         ...
# 507  POINT (78.49287 17.56112)
# 508  POINT (78.48754 17.37519)
# 509  POINT (78.30811 17.55512)
# 510  POINT (78.44326 17.35533)
# 511  POINT (87.53217 21.91297)
#
# [512 rows x 8 columns]

# %% [markdown]
# # Archivos imágen

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
I=plt.imread(ruta+'imagen.bmp')
I.shape
# Out:
# (199, 309, 4)

# %%
plt.imshow(I)

# %%
I[0,0,3] # Pixel (x,y) matríz 3. R, G, B (3)
# Out:
# 255

# %%
c=0.5*np.ones((199,309,4))

# %%
c[:,:,:3]=I[:,:,:3]/255
plt.imshow(c)

# %%
c[0,0,0]
# Out:
# 1.0

# %%
# Obtención de una matríz en escala de grises
G=I.mean(axis=2)
G.shape
# Out:
# (199, 309)

# %%
G=G/255
G[0,0]
# Out:
# 1.0

# %%
plt.imshow(G, cmap='gray')

# %%
plt.imshow(G)
